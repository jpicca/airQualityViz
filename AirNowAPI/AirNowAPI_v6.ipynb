# %% [markdown]
# #### Import Dependencies & needed API Keys

# %%
import pandas as pd
import requests
import datetime
from datetime import datetime as dt
from time import sleep

from Resources.config import airNowApiKeyShane, airNowApiKeyShane2, airNowApiKeyAudelia, airNowApiKeyCenez, airNowApiKeyJoseph, airNowApiKeyJoey
from Resources.largest_combined_statistical_areas_t25 import largest_combined_statistical_areas

# %% [markdown]
# #### Setup counters, empty list to hold data amd API Key Variables to be used

# %%
# Setup Counters
counterAttempts = 0
counterAttemptsPerAPI = 0
counterAPI = 1

# Setup empty list
apiData = []

# Setup API Key Variables
airNowApiKey1 = airNowApiKeyShane
airNowApiKey2 = airNowApiKeyAudelia
airNowApiKey3 = airNowApiKeyCenez
airNowApiKey4 = airNowApiKeyJoseph
airNowApiKey5 = airNowApiKeyJoey
airNowApiKey6 = airNowApiKeyShane2

# %% [markdown]
# #### Create a list of dates to iterate through (first 7 days of each month, 2015 to 2019)

# %%
# Set Date Range to use for API
# startDate = '2015-01-01'
startDate = '2020-04-01' # <-- for testing/example; comment out this line (3), uncomment line (2) above for actual use
endDate = '2020-04-30'

# Create a list of dates (from Start to End)
dateList = pd.date_range(startDate, endDate).strftime("%Y-%m-%d").tolist()
# print(dateList)

# Create empty list to append dates within a given range to in for loop
datesToUseList = []

# Loop through dateList and append only dates that are within the range of days (of month) to the datesToUseList
for date in dateList:
    day = (datetime.datetime.strptime(date, "%Y-%m-%d")).day
    if day in range(1,8):
        datesToUseList.append(date)
#         print(f"KEEP: {date} is in range")
    else:
#         print(f"REMOVE: {date} is OUT OF RANGE")
        pass

# print(datesToUseList)
len(datesToUseList)
# Out:
# 7

# %% [markdown]
# #### Setup API Call Function and with URL, API Key, and variables to pass through in the requests.get() API call

# %%
def apiCallLatLongHistorical(csaRank, csaFullName, csaPrimaryCity, csaPrimaryCityState, csaPopulation2018Estimate, csaPopulation2010Census, csaPrimaryCityLat, csaPrimaryCityLong, csaPrimaryCityZip, csaTimeZone, csaStandardTimeUtcOffset, csaDaylightSavingsTimeUtcOffset, csaSearchLat, csaSearchLong, csaSearchRadius, obsDate, obsTime, apiKey, apiKeyUsed, counterAttempts, counterAttemptsPerAPI, counterAPI):
    
    # Empty response list variable every time function is called
    response = []
    
    # Set API Parameters to be passed through to API requests.get
    params = {}
    params["baseURL"] = "http://www.airnowapi.org/aq/observation/latLong/historical/?format=application/json"
#     params["baseURL"] = "http://www.airnowapi.org/aq/observation/zipCode/historical/?format=application/json"
    params["lat"] = f"{csaPrimaryCityLat}"
    params["long"] = f"{csaPrimaryCityLong}"
    params["zip"] = f"{csaPrimaryCityZip}"
    params["obsDate"] = f"{obsDate}"
    params["obsTime"] = "00-0000" # f"{obsTime}"
    params["searchDistance"] = f"{csaSearchRadius}"
    params["apiKey"] = apiKey


    # Build API Request URL, passing through parameters - by LAT/LONG
    requestURL = params["baseURL"] \
                + "&latitude=" + params["lat"] \
                + "&longitude=" + params["long"] \
                + "&date=" + params["obsDate"] \
                + "T" + params["obsTime"] \
                + "&distance=" + params["searchDistance"] \
                + "&API_KEY=" + params["apiKey"]
    
#     # Build API Request URL, passing through parameters - by ZIP CODE
#     requestURL = params["baseURL"] \
#                 + "&zipCode=" + params["zip"] \
#                 + "&date=" + params["obsDate"] \
#                 + "T" + params["obsTime"] \
#                 + "&distance=" + params["searchDistance"] \
#                 + "&API_KEY=" + params["apiKey"]

    
    # Logger: Print status message
    print("--------------------------------------------------")
    print("Requesting AirNow API Data for...")
    print("     **************************************************")
    print(dt.now().strftime('%Y-%m-%d.%H.%M.%S'))
    print(f"CSA: {csaFullName} | CITY: {csaPrimaryCity}, {csaPrimaryCityState} | LAT: {params['lat']} | LONG: {params['long']} | DATE: {params['obsDate']}")
#     print(f"CSA: {csaFullName} | CITY: {csaPrimaryCity}, {csaPrimaryCityState} | ZIP: {params['zip']} | DATE: {params['obsDate']}")
    print(f"ATTEMPT:{counterAttempts} | ATTEMPT PER BATCH/API: {counterAttemptsPerAPI} | BATCH/API: {counterAPI} | API Key Used: {apiKeyUsed}")
    print("     **************************************************")
#     print(requestURL)
    
    # Set up error handling in the even there is an error in the API requests.get()
    try:
        
        # Execute requests.get, passing through built requestURL
        response = requests.get(requestURL).json()
        responseCode = requests.get(requestURL)
        
        # Results sum and response Code:
        print("     **************************************************")
        print(f"Number of results found: {len(response)}")
        print(f"Response Code: {responseCode}")
        print("     **************************************************")

        # Loop through response, appending each element (dictionary) as a new item in the apiData list
        for i in range(len(response)):
            
            # Break out the response "Category" Key value (another dictionary) into two separate values (to easily convert later to a csv, if needed)
            response[i]["AQICategoryNumber"] = response[i]["Category"]["Number"]
            response[i]["AQICategory"] = response[i]["Category"]["Name"]
            
            # Delete the "Category" Key value (another dictionary) from response since separate key: values were created and this is no longer needed
            del response[i]["Category"]
            
            # Add values brought in from the largest_combined_statistical_areas dictionary / json object to the response
            response[i]["csaRank"] = csaRank
            response[i]["csaFullName"] = csaFullName
            response[i]["csaPrimaryCity"] = csaPrimaryCity
            response[i]["csaPrimaryCityState"] = csaPrimaryCityState
            response[i]["csaPopulation2018Estimate"] = csaPopulation2018Estimate
            response[i]["csaPopulation2010Census"] = csaPopulation2010Census
            response[i]["csaPrimaryCityLat"] = csaPrimaryCityLat
            response[i]["csaPrimaryCityLong"] = csaPrimaryCityLong
            response[i]["csaPrimaryCityZip"] = csaPrimaryCityZip
          
            response[i]["csaTimeZone"] = csaTimeZone
            response[i]["csaStandardTimeUtcOffset"] = csaStandardTimeUtcOffset
            response[i]["csaDaylightSavingsTimeUtcOffset"] = csaDaylightSavingsTimeUtcOffset
            response[i]["csaSearchLat"] = csaSearchLat
            response[i]["csaSearchLong"] = csaSearchLong
            response[i]["csaSearchRadius"] = csaSearchRadius
          
            # Append the response to the apiData list
            apiData.append(response[i])

    except Exception as e:
        print(f"ERROR: Unable to perform AirNow API request for CITY: CSA: {csaFullName} | CITY: {csaPrimaryCity}, {csaPrimaryCityState} | LAT: {params['lat']} | LONG: {params['long']} | DATE: {params['obsDate']}.")
#         print(f"ERROR: Unable to perform AirNow API request for CITY: CSA: {csaFullName} | CITY: {csaPrimaryCity}, {csaPrimaryCityState} | ZIP: {params['zip']} | DATE: {params['obsDate']}.")
        print("%s" % e)
        print("--------------------------------------------------")
        pass

# %% [markdown]
# #### Loop through cities and dates, while updating variables and passing them through to the apiCallLatLongHistorical Function

# %%
# Loop through cities in the largest_combined_statistical_areas dictionary / json object
for csa in largest_combined_statistical_areas:
    
    # Loop through datesToUseList, calling the apiCallLatLongHistorical function, passing through variables    
    for date in datesToUseList:
    
        # Set varaiable values to pass into the apiCallLatLongHistorical function
        csaRank = csa["csa_rank"]
        csaFullName = csa["csa_name"]
        csaPrimaryCity = csa["primary_city"]
        csaPrimaryCityState = csa["primary_city_state"]
        csaPopulation2018Estimate = csa["population"]["2018_estimate"]
        csaPopulation2010Census = csa["population"]["2010_census"]
        csaPrimaryCityLat = csa["primary_city_location"]["lat"]
        csaPrimaryCityLong = csa["primary_city_location"]["long"]
        csaPrimaryCityZip = csa["primary_city_location"]["zip_code"]
        
        csaTimeZone = csa["timezone_params"]["timezone"]
        csaStandardTimeUtcOffset = csa["timezone_params"]["utc_offset"]["standard_time"]
        csaDaylightSavingsTimeUtcOffset = csa["timezone_params"]["utc_offset"]["daylight_savings_time"]
        csaSearchLat = csa["search_params"]["closest_monitoring_station"]["lat"]
        csaSearchLong = csa["search_params"]["closest_monitoring_station"]["long"]
        csaSearchRadius = csa["search_params"]["closest_monitoring_station"]["search_radius"]
        
        # Update overall attempt counter
        counterAttempts += 1
        
        # Once 250 attempts have been made for all six API Keys, reset counterAttemptsPerAPI, counterAPI and apiKey then sleep for one hour (3600 seconds)
#         if counterAttemptsPerAPI >= 250 and counterAPI >= 6:
        if counterAttemptsPerAPI >= 7 and counterAPI >= 6: # <-- for testing/example; comment out this line (30), uncomment line (29) above for actual use
            counterAttemptsPerAPI = 1
            counterAPI = 1
            apiKey = airNowApiKey1
            print("*****  250 per API for all APIs avialable reached | RESET counterAttemptsPerAPI, counterAPI, apiKey & SLEEP  *****")
            sleep(3600)
#             sleep(3)

        # Once 250 attempts have been made for the currently used API Key, update counterAPI so a new apiKey is used next time through, reset counterAttemptsPerAPI
#         elif counterAttemptsPerAPI >= 250:
        elif counterAttemptsPerAPI >= 7: # <-- for testing/example; comment out this line (40), uncomment line (39) above for actual use
            counterAPI += 1
            counterAttemptsPerAPI = 1
            print("*****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****")
            
        else:
            counterAttemptsPerAPI += 1

        # Set apiKey variable based on the counterAPI variable
        if counterAPI == 1:
            apiKey = airNowApiKey1
            apiKeyUsed = "airNowApiKey1"
        elif counterAPI == 2:
            apiKey = airNowApiKey2
            apiKeyUsed = "airNowApiKey2"
        elif counterAPI == 3:
            apiKey = airNowApiKey3
            apiKeyUsed = "airNowApiKey3"
        elif counterAPI == 4:
            apiKey = airNowApiKey4
            apiKeyUsed = "airNowApiKey4"
        elif counterAPI == 5:
            apiKey = airNowApiKey5
            apiKeyUsed = "airNowApiKey5"
        elif counterAPI == 6:
            apiKey = airNowApiKey6
            apiKeyUsed = "airNowApiKey6"
        
        # Call the apiCallLatLongHistorical function, passing through updated variables as parameters
        apiCallLatLongHistorical(csaRank, csaFullName, csaPrimaryCity, csaPrimaryCityState, csaPopulation2018Estimate, csaPopulation2010Census, csaPrimaryCityLat, csaPrimaryCityLong, csaPrimaryCityZip, csaTimeZone, csaStandardTimeUtcOffset, csaDaylightSavingsTimeUtcOffset, csaSearchLat, csaSearchLong, csaSearchRadius, date, "00-0000", apiKey, apiKeyUsed, counterAttempts, counterAttemptsPerAPI, counterAPI)
# Out:
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.20
# CSA: New York-Newark, NY-NJ-CT-PA Combined Statistical Area | CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2020-04-01
# ATTEMPT:1 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.20
# CSA: New York-Newark, NY-NJ-CT-PA Combined Statistical Area | CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2020-04-02
# ATTEMPT:2 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.21
# CSA: New York-Newark, NY-NJ-CT-PA Combined Statistical Area | CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2020-04-03
# ATTEMPT:3 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.21
# CSA: New York-Newark, NY-NJ-CT-PA Combined Statistical Area | CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2020-04-04
# ATTEMPT:4 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.22
# CSA: New York-Newark, NY-NJ-CT-PA Combined Statistical Area | CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2020-04-05
# ATTEMPT:5 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.22
# CSA: New York-Newark, NY-NJ-CT-PA Combined Statistical Area | CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2020-04-06
# ATTEMPT:6 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.23
# CSA: New York-Newark, NY-NJ-CT-PA Combined Statistical Area | CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2020-04-07
# ATTEMPT:7 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# *****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.23
# CSA: Los Angeles-Long Beach, CA Combined Statistical Area | CITY: Los Angeles, CA | LAT: 34.0522 | LONG: -118.2437 | DATE: 2020-04-01
# ATTEMPT:8 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.24
# CSA: Los Angeles-Long Beach, CA Combined Statistical Area | CITY: Los Angeles, CA | LAT: 34.0522 | LONG: -118.2437 | DATE: 2020-04-02
# ATTEMPT:9 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.24
# CSA: Los Angeles-Long Beach, CA Combined Statistical Area | CITY: Los Angeles, CA | LAT: 34.0522 | LONG: -118.2437 | DATE: 2020-04-03
# ATTEMPT:10 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.25
# CSA: Los Angeles-Long Beach, CA Combined Statistical Area | CITY: Los Angeles, CA | LAT: 34.0522 | LONG: -118.2437 | DATE: 2020-04-04
# ATTEMPT:11 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.25
# CSA: Los Angeles-Long Beach, CA Combined Statistical Area | CITY: Los Angeles, CA | LAT: 34.0522 | LONG: -118.2437 | DATE: 2020-04-05
# ATTEMPT:12 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.26
# CSA: Los Angeles-Long Beach, CA Combined Statistical Area | CITY: Los Angeles, CA | LAT: 34.0522 | LONG: -118.2437 | DATE: 2020-04-06
# ATTEMPT:13 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.26
# CSA: Los Angeles-Long Beach, CA Combined Statistical Area | CITY: Los Angeles, CA | LAT: 34.0522 | LONG: -118.2437 | DATE: 2020-04-07
# ATTEMPT:14 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# *****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.27
# CSA: Chicago-Naperville, IL-IN-WI Combined Statistical Area | CITY: Chicago, IL | LAT: 41.8781 | LONG: -87.6298 | DATE: 2020-04-01
# ATTEMPT:15 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.27
# CSA: Chicago-Naperville, IL-IN-WI Combined Statistical Area | CITY: Chicago, IL | LAT: 41.8781 | LONG: -87.6298 | DATE: 2020-04-02
# ATTEMPT:16 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.28
# CSA: Chicago-Naperville, IL-IN-WI Combined Statistical Area | CITY: Chicago, IL | LAT: 41.8781 | LONG: -87.6298 | DATE: 2020-04-03
# ATTEMPT:17 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.28
# CSA: Chicago-Naperville, IL-IN-WI Combined Statistical Area | CITY: Chicago, IL | LAT: 41.8781 | LONG: -87.6298 | DATE: 2020-04-04
# ATTEMPT:18 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.29
# CSA: Chicago-Naperville, IL-IN-WI Combined Statistical Area | CITY: Chicago, IL | LAT: 41.8781 | LONG: -87.6298 | DATE: 2020-04-05
# ATTEMPT:19 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.29
# CSA: Chicago-Naperville, IL-IN-WI Combined Statistical Area | CITY: Chicago, IL | LAT: 41.8781 | LONG: -87.6298 | DATE: 2020-04-06
# ATTEMPT:20 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.30
# CSA: Chicago-Naperville, IL-IN-WI Combined Statistical Area | CITY: Chicago, IL | LAT: 41.8781 | LONG: -87.6298 | DATE: 2020-04-07
# ATTEMPT:21 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# *****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.30
# CSA: Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area | CITY: Washington, DC | LAT: 38.9072 | LONG: -77.0369 | DATE: 2020-04-01
# ATTEMPT:22 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.31
# CSA: Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area | CITY: Washington, DC | LAT: 38.9072 | LONG: -77.0369 | DATE: 2020-04-02
# ATTEMPT:23 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.32
# CSA: Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area | CITY: Washington, DC | LAT: 38.9072 | LONG: -77.0369 | DATE: 2020-04-03
# ATTEMPT:24 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.32
# CSA: Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area | CITY: Washington, DC | LAT: 38.9072 | LONG: -77.0369 | DATE: 2020-04-04
# ATTEMPT:25 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.33
# CSA: Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area | CITY: Washington, DC | LAT: 38.9072 | LONG: -77.0369 | DATE: 2020-04-05
# ATTEMPT:26 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.33
# CSA: Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area | CITY: Washington, DC | LAT: 38.9072 | LONG: -77.0369 | DATE: 2020-04-06
# ATTEMPT:27 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.34
# CSA: Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area | CITY: Washington, DC | LAT: 38.9072 | LONG: -77.0369 | DATE: 2020-04-07
# ATTEMPT:28 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# *****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.34
# CSA: San Jose-San Francisco-Oakland, CA Combined Statistical Area | CITY: San Francisco, CA | LAT: 37.7749 | LONG: -122.4194 | DATE: 2020-04-01
# ATTEMPT:29 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.35
# CSA: San Jose-San Francisco-Oakland, CA Combined Statistical Area | CITY: San Francisco, CA | LAT: 37.7749 | LONG: -122.4194 | DATE: 2020-04-02
# ATTEMPT:30 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.35
# CSA: San Jose-San Francisco-Oakland, CA Combined Statistical Area | CITY: San Francisco, CA | LAT: 37.7749 | LONG: -122.4194 | DATE: 2020-04-03
# ATTEMPT:31 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.35
# CSA: San Jose-San Francisco-Oakland, CA Combined Statistical Area | CITY: San Francisco, CA | LAT: 37.7749 | LONG: -122.4194 | DATE: 2020-04-04
# ATTEMPT:32 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.36
# CSA: San Jose-San Francisco-Oakland, CA Combined Statistical Area | CITY: San Francisco, CA | LAT: 37.7749 | LONG: -122.4194 | DATE: 2020-04-05
# ATTEMPT:33 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.36
# CSA: San Jose-San Francisco-Oakland, CA Combined Statistical Area | CITY: San Francisco, CA | LAT: 37.7749 | LONG: -122.4194 | DATE: 2020-04-06
# ATTEMPT:34 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.37
# CSA: San Jose-San Francisco-Oakland, CA Combined Statistical Area | CITY: San Francisco, CA | LAT: 37.7749 | LONG: -122.4194 | DATE: 2020-04-07
# ATTEMPT:35 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# *****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.37
# CSA: Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area | CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2020-04-01
# ATTEMPT:36 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.38
# CSA: Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area | CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2020-04-02
# ATTEMPT:37 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.38
# CSA: Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area | CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2020-04-03
# ATTEMPT:38 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.39
# CSA: Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area | CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2020-04-04
# ATTEMPT:39 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.39
# CSA: Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area | CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2020-04-05
# ATTEMPT:40 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.40
# CSA: Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area | CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2020-04-06
# ATTEMPT:41 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.40
# CSA: Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area | CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2020-04-07
# ATTEMPT:42 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# *****  250 per API for all APIs avialable reached | RESET counterAttemptsPerAPI, counterAPI, apiKey & SLEEP  *****
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.44
# CSA: Dallas-Fort Worth, TX-OK Combined Statistical Area | CITY: Dallas, TX | LAT: 32.7767 | LONG: -96.797 | DATE: 2020-04-01
# ATTEMPT:43 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.44
# CSA: Dallas-Fort Worth, TX-OK Combined Statistical Area | CITY: Dallas, TX | LAT: 32.7767 | LONG: -96.797 | DATE: 2020-04-02
# ATTEMPT:44 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.45
# CSA: Dallas-Fort Worth, TX-OK Combined Statistical Area | CITY: Dallas, TX | LAT: 32.7767 | LONG: -96.797 | DATE: 2020-04-03
# ATTEMPT:45 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.45
# CSA: Dallas-Fort Worth, TX-OK Combined Statistical Area | CITY: Dallas, TX | LAT: 32.7767 | LONG: -96.797 | DATE: 2020-04-04
# ATTEMPT:46 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.46
# CSA: Dallas-Fort Worth, TX-OK Combined Statistical Area | CITY: Dallas, TX | LAT: 32.7767 | LONG: -96.797 | DATE: 2020-04-05
# ATTEMPT:47 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.46
# CSA: Dallas-Fort Worth, TX-OK Combined Statistical Area | CITY: Dallas, TX | LAT: 32.7767 | LONG: -96.797 | DATE: 2020-04-06
# ATTEMPT:48 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.47
# CSA: Dallas-Fort Worth, TX-OK Combined Statistical Area | CITY: Dallas, TX | LAT: 32.7767 | LONG: -96.797 | DATE: 2020-04-07
# ATTEMPT:49 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# *****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.47
# CSA: Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area | CITY: Philadelphia, PA | LAT: 39.9526 | LONG: -75.1652 | DATE: 2020-04-01
# ATTEMPT:50 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.48
# CSA: Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area | CITY: Philadelphia, PA | LAT: 39.9526 | LONG: -75.1652 | DATE: 2020-04-02
# ATTEMPT:51 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.48
# CSA: Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area | CITY: Philadelphia, PA | LAT: 39.9526 | LONG: -75.1652 | DATE: 2020-04-03
# ATTEMPT:52 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.49
# CSA: Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area | CITY: Philadelphia, PA | LAT: 39.9526 | LONG: -75.1652 | DATE: 2020-04-04
# ATTEMPT:53 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.49
# CSA: Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area | CITY: Philadelphia, PA | LAT: 39.9526 | LONG: -75.1652 | DATE: 2020-04-05
# ATTEMPT:54 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.50
# CSA: Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area | CITY: Philadelphia, PA | LAT: 39.9526 | LONG: -75.1652 | DATE: 2020-04-06
# ATTEMPT:55 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.50
# CSA: Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area | CITY: Philadelphia, PA | LAT: 39.9526 | LONG: -75.1652 | DATE: 2020-04-07
# ATTEMPT:56 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 2 | API Key Used: airNowApiKey2
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# *****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.50
# CSA: Houston-The Woodlands, TX Combined Statistical Area | CITY: Houston, TX | LAT: 29.7604 | LONG: -95.3698 | DATE: 2020-04-01
# ATTEMPT:57 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.51
# CSA: Houston-The Woodlands, TX Combined Statistical Area | CITY: Houston, TX | LAT: 29.7604 | LONG: -95.3698 | DATE: 2020-04-02
# ATTEMPT:58 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.51
# CSA: Houston-The Woodlands, TX Combined Statistical Area | CITY: Houston, TX | LAT: 29.7604 | LONG: -95.3698 | DATE: 2020-04-03
# ATTEMPT:59 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.52
# CSA: Houston-The Woodlands, TX Combined Statistical Area | CITY: Houston, TX | LAT: 29.7604 | LONG: -95.3698 | DATE: 2020-04-04
# ATTEMPT:60 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.53
# CSA: Houston-The Woodlands, TX Combined Statistical Area | CITY: Houston, TX | LAT: 29.7604 | LONG: -95.3698 | DATE: 2020-04-05
# ATTEMPT:61 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.53
# CSA: Houston-The Woodlands, TX Combined Statistical Area | CITY: Houston, TX | LAT: 29.7604 | LONG: -95.3698 | DATE: 2020-04-06
# ATTEMPT:62 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.54
# CSA: Houston-The Woodlands, TX Combined Statistical Area | CITY: Houston, TX | LAT: 29.7604 | LONG: -95.3698 | DATE: 2020-04-07
# ATTEMPT:63 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 3 | API Key Used: airNowApiKey3
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# *****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.54
# CSA: Miami-Port St. Lucie-Fort Lauderdale, FL Combined Statistical Area | CITY: Miami, FL | LAT: 25.7617 | LONG: -80.1918 | DATE: 2020-04-01
# ATTEMPT:64 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.55
# CSA: Miami-Port St. Lucie-Fort Lauderdale, FL Combined Statistical Area | CITY: Miami, FL | LAT: 25.7617 | LONG: -80.1918 | DATE: 2020-04-02
# ATTEMPT:65 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 0
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.55
# CSA: Miami-Port St. Lucie-Fort Lauderdale, FL Combined Statistical Area | CITY: Miami, FL | LAT: 25.7617 | LONG: -80.1918 | DATE: 2020-04-03
# ATTEMPT:66 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 0
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.56
# CSA: Miami-Port St. Lucie-Fort Lauderdale, FL Combined Statistical Area | CITY: Miami, FL | LAT: 25.7617 | LONG: -80.1918 | DATE: 2020-04-04
# ATTEMPT:67 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.56
# CSA: Miami-Port St. Lucie-Fort Lauderdale, FL Combined Statistical Area | CITY: Miami, FL | LAT: 25.7617 | LONG: -80.1918 | DATE: 2020-04-05
# ATTEMPT:68 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.57
# CSA: Miami-Port St. Lucie-Fort Lauderdale, FL Combined Statistical Area | CITY: Miami, FL | LAT: 25.7617 | LONG: -80.1918 | DATE: 2020-04-06
# ATTEMPT:69 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.57
# CSA: Miami-Port St. Lucie-Fort Lauderdale, FL Combined Statistical Area | CITY: Miami, FL | LAT: 25.7617 | LONG: -80.1918 | DATE: 2020-04-07
# ATTEMPT:70 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# *****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.57
# CSA: Atlanta–Athens-Clarke County–Sandy Springs, GA-AL Combined Statistical Area | CITY: Atlanta, GA | LAT: 33.749 | LONG: -84.388 | DATE: 2020-04-01
# ATTEMPT:71 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.58
# CSA: Atlanta–Athens-Clarke County–Sandy Springs, GA-AL Combined Statistical Area | CITY: Atlanta, GA | LAT: 33.749 | LONG: -84.388 | DATE: 2020-04-02
# ATTEMPT:72 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.58
# CSA: Atlanta–Athens-Clarke County–Sandy Springs, GA-AL Combined Statistical Area | CITY: Atlanta, GA | LAT: 33.749 | LONG: -84.388 | DATE: 2020-04-03
# ATTEMPT:73 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.59
# CSA: Atlanta–Athens-Clarke County–Sandy Springs, GA-AL Combined Statistical Area | CITY: Atlanta, GA | LAT: 33.749 | LONG: -84.388 | DATE: 2020-04-04
# ATTEMPT:74 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.28.59
# CSA: Atlanta–Athens-Clarke County–Sandy Springs, GA-AL Combined Statistical Area | CITY: Atlanta, GA | LAT: 33.749 | LONG: -84.388 | DATE: 2020-04-05
# ATTEMPT:75 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.00
# CSA: Atlanta–Athens-Clarke County–Sandy Springs, GA-AL Combined Statistical Area | CITY: Atlanta, GA | LAT: 33.749 | LONG: -84.388 | DATE: 2020-04-06
# ATTEMPT:76 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.00
# CSA: Atlanta–Athens-Clarke County–Sandy Springs, GA-AL Combined Statistical Area | CITY: Atlanta, GA | LAT: 33.749 | LONG: -84.388 | DATE: 2020-04-07
# ATTEMPT:77 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# ...
# ATTEMPT:150 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.40
# CSA: Sacramento-Roseville, CA Combined Statistical Area | CITY: Sacramento, CA | LAT: 38.5816 | LONG: -121.4944 | DATE: 2020-04-04
# ATTEMPT:151 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.41
# CSA: Sacramento-Roseville, CA Combined Statistical Area | CITY: Sacramento, CA | LAT: 38.5816 | LONG: -121.4944 | DATE: 2020-04-05
# ATTEMPT:152 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.41
# CSA: Sacramento-Roseville, CA Combined Statistical Area | CITY: Sacramento, CA | LAT: 38.5816 | LONG: -121.4944 | DATE: 2020-04-06
# ATTEMPT:153 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.42
# CSA: Sacramento-Roseville, CA Combined Statistical Area | CITY: Sacramento, CA | LAT: 38.5816 | LONG: -121.4944 | DATE: 2020-04-07
# ATTEMPT:154 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 4 | API Key Used: airNowApiKey4
#      **************************************************
#      **************************************************
# Number of results found: 3
# Response Code: <Response [200]>
#      **************************************************
# *****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.42
# CSA: Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area | CITY: Pittsburgh, PA | LAT: 40.4406 | LONG: -79.9959 | DATE: 2020-04-01
# ATTEMPT:155 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.43
# CSA: Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area | CITY: Pittsburgh, PA | LAT: 40.4406 | LONG: -79.9959 | DATE: 2020-04-02
# ATTEMPT:156 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.43
# CSA: Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area | CITY: Pittsburgh, PA | LAT: 40.4406 | LONG: -79.9959 | DATE: 2020-04-03
# ATTEMPT:157 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.44
# CSA: Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area | CITY: Pittsburgh, PA | LAT: 40.4406 | LONG: -79.9959 | DATE: 2020-04-04
# ATTEMPT:158 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.45
# CSA: Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area | CITY: Pittsburgh, PA | LAT: 40.4406 | LONG: -79.9959 | DATE: 2020-04-05
# ATTEMPT:159 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.46
# CSA: Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area | CITY: Pittsburgh, PA | LAT: 40.4406 | LONG: -79.9959 | DATE: 2020-04-06
# ATTEMPT:160 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.46
# CSA: Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area | CITY: Pittsburgh, PA | LAT: 40.4406 | LONG: -79.9959 | DATE: 2020-04-07
# ATTEMPT:161 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 5 | API Key Used: airNowApiKey5
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# *****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.47
# CSA: Salt Lake City-Provo-Orem, UT Combined Statistical Area | CITY: Salt Lake City, UT | LAT: 40.7608 | LONG: -111.891 | DATE: 2020-04-01
# ATTEMPT:162 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.47
# CSA: Salt Lake City-Provo-Orem, UT Combined Statistical Area | CITY: Salt Lake City, UT | LAT: 40.7608 | LONG: -111.891 | DATE: 2020-04-02
# ATTEMPT:163 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.48
# CSA: Salt Lake City-Provo-Orem, UT Combined Statistical Area | CITY: Salt Lake City, UT | LAT: 40.7608 | LONG: -111.891 | DATE: 2020-04-03
# ATTEMPT:164 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.48
# CSA: Salt Lake City-Provo-Orem, UT Combined Statistical Area | CITY: Salt Lake City, UT | LAT: 40.7608 | LONG: -111.891 | DATE: 2020-04-04
# ATTEMPT:165 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.48
# CSA: Salt Lake City-Provo-Orem, UT Combined Statistical Area | CITY: Salt Lake City, UT | LAT: 40.7608 | LONG: -111.891 | DATE: 2020-04-05
# ATTEMPT:166 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.49
# CSA: Salt Lake City-Provo-Orem, UT Combined Statistical Area | CITY: Salt Lake City, UT | LAT: 40.7608 | LONG: -111.891 | DATE: 2020-04-06
# ATTEMPT:167 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.49
# CSA: Salt Lake City-Provo-Orem, UT Combined Statistical Area | CITY: Salt Lake City, UT | LAT: 40.7608 | LONG: -111.891 | DATE: 2020-04-07
# ATTEMPT:168 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 6 | API Key Used: airNowApiKey6
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# *****  250 per API for all APIs avialable reached | RESET counterAttemptsPerAPI, counterAPI, apiKey & SLEEP  *****
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.53
# CSA: San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area | CITY: San Antonio, TX | LAT: 29.4241 | LONG: -98.4936 | DATE: 2020-04-01
# ATTEMPT:169 | ATTEMPT PER BATCH/API: 1 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.53
# CSA: San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area | CITY: San Antonio, TX | LAT: 29.4241 | LONG: -98.4936 | DATE: 2020-04-02
# ATTEMPT:170 | ATTEMPT PER BATCH/API: 2 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.53
# CSA: San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area | CITY: San Antonio, TX | LAT: 29.4241 | LONG: -98.4936 | DATE: 2020-04-03
# ATTEMPT:171 | ATTEMPT PER BATCH/API: 3 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.54
# CSA: San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area | CITY: San Antonio, TX | LAT: 29.4241 | LONG: -98.4936 | DATE: 2020-04-04
# ATTEMPT:172 | ATTEMPT PER BATCH/API: 4 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.54
# CSA: San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area | CITY: San Antonio, TX | LAT: 29.4241 | LONG: -98.4936 | DATE: 2020-04-05
# ATTEMPT:173 | ATTEMPT PER BATCH/API: 5 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.55
# CSA: San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area | CITY: San Antonio, TX | LAT: 29.4241 | LONG: -98.4936 | DATE: 2020-04-06
# ATTEMPT:174 | ATTEMPT PER BATCH/API: 6 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# 2020-04-17.16.29.55
# CSA: San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area | CITY: San Antonio, TX | LAT: 29.4241 | LONG: -98.4936 | DATE: 2020-04-07
# ATTEMPT:175 | ATTEMPT PER BATCH/API: 7 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
#      **************************************************
# Number of results found: 2
# Response Code: <Response [200]>
#      **************************************************

# %% [markdown]
# #### Check the number of records in the apiData list and visualize the data

# %%
len(apiData)
# Out:
# 414

# %%
apiData
# Out:
# [{'DateObserved': '2020-04-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'OZONE',
#   'AQI': 39,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'PM2.5',
#   'AQI': 27,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-02 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'OZONE',
#   'AQI': 39,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-02 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'PM2.5',
#   'AQI': 13,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-03 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'OZONE',
#   'AQI': 29,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-03 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'PM2.5',
#   'AQI': 13,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-04 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'OZONE',
#   'AQI': 34,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-04 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'PM2.5',
#   'AQI': 19,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-05 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'OZONE',
#   'AQI': 20,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-05 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'PM2.5',
#   'AQI': 52,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-06 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'OZONE',
#   'AQI': 39,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-06 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'PM2.5',
#   'AQI': 35,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'OZONE',
#   'AQI': 42,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'PM2.5',
#   'AQI': 24,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'OZONE',
#   'AQI': 51,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'PM2.5',
#   'AQI': 52,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'PM10',
#   'AQI': 26,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-02 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'OZONE',
#   'AQI': 49,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-02 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'PM2.5',
#   'AQI': 44,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-02 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'PM10',
#   'AQI': 24,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-03 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'OZONE',
#   'AQI': 49,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-03 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'PM2.5',
#   'AQI': 46,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-04 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'OZONE',
#   'AQI': 50,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-04 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'PM2.5',
#   'AQI': 43,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-05 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'OZONE',
#   'AQI': 36,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-05 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'PM2.5',
#   'AQI': 16,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-06 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'OZONE',
#   'AQI': 41,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-06 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'PM2.5',
#   'AQI': 14,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'OZONE',
#   'AQI': 40,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'PM2.5',
#   'AQI': 19,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'OZONE',
#   'AQI': 29,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'PM2.5',
#   'AQI': 57,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-02 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'OZONE',
#   'AQI': 40,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-02 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'PM2.5',
#   'AQI': 53,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-03 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'OZONE',
#   'AQI': 48,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-03 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'PM2.5',
#   'AQI': 61,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-04 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'OZONE',
#   'AQI': 29,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-04 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'PM2.5',
#   'AQI': 34,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-05 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'OZONE',
#   'AQI': 43,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-05 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'PM2.5',
#   'AQI': 33,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-06 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'OZONE',
#   'AQI': 44,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-06 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'PM2.5',
#   'AQI': 52,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'OZONE',
#   'AQI': 43,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'PM2.5',
#   'AQI': 56,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'OZONE',
#   'AQI': 36,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM2.5',
#   'AQI': 22,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM10',
#   'AQI': 7,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-02 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'OZONE',
#   'AQI': 44,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-02 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM2.5',
#   'AQI': 16,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-02 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM10',
#   'AQI': 8,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-03 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'OZONE',
#   'AQI': 45,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-03 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM2.5',
#   'AQI': 12,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-03 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM10',
#   'AQI': 8,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-04 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'OZONE',
#   'AQI': 33,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-04 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM2.5',
#   'AQI': 13,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-04 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM10',
#   'AQI': 5,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-05 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'OZONE',
#   'AQI': 43,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-05 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM2.5',
#   'AQI': 25,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-05 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM10',
#   'AQI': 10,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-06 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'OZONE',
# ...
#   'AQICategory': 'Good',
#   'csaRank': 24,
#   'csaFullName': 'Salt Lake City-Provo-Orem, UT Combined Statistical Area',
#   'csaPrimaryCity': 'Salt Lake City',
#   'csaPrimaryCityState': 'UT',
#   'csaPopulation2018Estimate': 2606548,
#   'csaPopulation2010Census': 2271696,
#   'csaPrimaryCityLat': 40.7608,
#   'csaPrimaryCityLong': -111.891,
#   'csaPrimaryCityZip': '84101',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-06:00',
#   'csaSearchLat': 40.777,
#   'csaSearchLong': -111.93,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-05 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'MST',
#   'ReportingArea': 'Salt Lake City',
#   'StateCode': 'UT',
#   'Latitude': 40.777,
#   'Longitude': -111.93,
#   'ParameterName': 'PM2.5',
#   'AQI': 23,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 24,
#   'csaFullName': 'Salt Lake City-Provo-Orem, UT Combined Statistical Area',
#   'csaPrimaryCity': 'Salt Lake City',
#   'csaPrimaryCityState': 'UT',
#   'csaPopulation2018Estimate': 2606548,
#   'csaPopulation2010Census': 2271696,
#   'csaPrimaryCityLat': 40.7608,
#   'csaPrimaryCityLong': -111.891,
#   'csaPrimaryCityZip': '84101',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-06:00',
#   'csaSearchLat': 40.777,
#   'csaSearchLong': -111.93,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-06 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'MST',
#   'ReportingArea': 'Salt Lake City',
#   'StateCode': 'UT',
#   'Latitude': 40.777,
#   'Longitude': -111.93,
#   'ParameterName': 'OZONE',
#   'AQI': 43,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 24,
#   'csaFullName': 'Salt Lake City-Provo-Orem, UT Combined Statistical Area',
#   'csaPrimaryCity': 'Salt Lake City',
#   'csaPrimaryCityState': 'UT',
#   'csaPopulation2018Estimate': 2606548,
#   'csaPopulation2010Census': 2271696,
#   'csaPrimaryCityLat': 40.7608,
#   'csaPrimaryCityLong': -111.891,
#   'csaPrimaryCityZip': '84101',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-06:00',
#   'csaSearchLat': 40.777,
#   'csaSearchLong': -111.93,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-06 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'MST',
#   'ReportingArea': 'Salt Lake City',
#   'StateCode': 'UT',
#   'Latitude': 40.777,
#   'Longitude': -111.93,
#   'ParameterName': 'PM2.5',
#   'AQI': 22,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 24,
#   'csaFullName': 'Salt Lake City-Provo-Orem, UT Combined Statistical Area',
#   'csaPrimaryCity': 'Salt Lake City',
#   'csaPrimaryCityState': 'UT',
#   'csaPopulation2018Estimate': 2606548,
#   'csaPopulation2010Census': 2271696,
#   'csaPrimaryCityLat': 40.7608,
#   'csaPrimaryCityLong': -111.891,
#   'csaPrimaryCityZip': '84101',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-06:00',
#   'csaSearchLat': 40.777,
#   'csaSearchLong': -111.93,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'MST',
#   'ReportingArea': 'Salt Lake City',
#   'StateCode': 'UT',
#   'Latitude': 40.777,
#   'Longitude': -111.93,
#   'ParameterName': 'OZONE',
#   'AQI': 43,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 24,
#   'csaFullName': 'Salt Lake City-Provo-Orem, UT Combined Statistical Area',
#   'csaPrimaryCity': 'Salt Lake City',
#   'csaPrimaryCityState': 'UT',
#   'csaPopulation2018Estimate': 2606548,
#   'csaPopulation2010Census': 2271696,
#   'csaPrimaryCityLat': 40.7608,
#   'csaPrimaryCityLong': -111.891,
#   'csaPrimaryCityZip': '84101',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-06:00',
#   'csaSearchLat': 40.777,
#   'csaSearchLong': -111.93,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'MST',
#   'ReportingArea': 'Salt Lake City',
#   'StateCode': 'UT',
#   'Latitude': 40.777,
#   'Longitude': -111.93,
#   'ParameterName': 'PM2.5',
#   'AQI': 25,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 24,
#   'csaFullName': 'Salt Lake City-Provo-Orem, UT Combined Statistical Area',
#   'csaPrimaryCity': 'Salt Lake City',
#   'csaPrimaryCityState': 'UT',
#   'csaPopulation2018Estimate': 2606548,
#   'csaPopulation2010Census': 2271696,
#   'csaPrimaryCityLat': 40.7608,
#   'csaPrimaryCityLong': -111.891,
#   'csaPrimaryCityZip': '84101',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-06:00',
#   'csaSearchLat': 40.777,
#   'csaSearchLong': -111.93,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'OZONE',
#   'AQI': 61,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'PM2.5',
#   'AQI': 26,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-02 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'OZONE',
#   'AQI': 30,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-02 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'PM2.5',
#   'AQI': 36,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-03 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'OZONE',
#   'AQI': 25,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-03 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'PM2.5',
#   'AQI': 37,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-04 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'OZONE',
#   'AQI': 22,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-04 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'PM2.5',
#   'AQI': 17,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-05 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'OZONE',
#   'AQI': 37,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-05 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'PM2.5',
#   'AQI': 43,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-06 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'OZONE',
#   'AQI': 41,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-06 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'PM2.5',
#   'AQI': 58,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'OZONE',
#   'AQI': 29,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'PM2.5',
#   'AQI': 58,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25}]

# %% [markdown]
# #### Create DataFrame holding the values from the apiData list

# %%
df = pd.DataFrame(apiData)

# Visualize the DataFrame
df
# Out:
#     DateObserved  HourObserved LocalTimeZone ReportingArea StateCode  \
# 0    2020-04-01              0           EST        Newark        NJ
# 1    2020-04-01              0           EST        Newark        NJ
# 2    2020-04-02              0           EST        Newark        NJ
# 3    2020-04-02              0           EST        Newark        NJ
# 4    2020-04-03              0           EST        Newark        NJ
# ..           ...           ...           ...           ...       ...
# 409  2020-04-05              0           CST   San Antonio        TX
# 410  2020-04-06              0           CST   San Antonio        TX
# 411  2020-04-06              0           CST   San Antonio        TX
# 412  2020-04-07              0           CST   San Antonio        TX
# 413  2020-04-07              0           CST   San Antonio        TX
#
#      Latitude  Longitude ParameterName  AQI  AQICategoryNumber  ...  \
# 0     40.7267   -74.1442         OZONE   39                  1  ...
# 1     40.7267   -74.1442         PM2.5   27                  1  ...
# 2     40.7267   -74.1442         OZONE   39                  1  ...
# 3     40.7267   -74.1442         PM2.5   13                  1  ...
# 4     40.7267   -74.1442         OZONE   29                  1  ...
# ..        ...        ...           ...  ...                ...  ...
# 409   29.4170   -98.4840         PM2.5   43                  1  ...
# 410   29.4170   -98.4840         OZONE   41                  1  ...
# 411   29.4170   -98.4840         PM2.5   58                  2  ...
# 412   29.4170   -98.4840         OZONE   29                  1  ...
# 413   29.4170   -98.4840         PM2.5   58                  2  ...
#
#     csaPopulation2010Census  csaPrimaryCityLat csaPrimaryCityLong  \
# 0                  22255491            40.7128           -74.0060
# 1                  22255491            40.7128           -74.0060
# 2                  22255491            40.7128           -74.0060
# 3                  22255491            40.7128           -74.0060
# 4                  22255491            40.7128           -74.0060
# ..                      ...                ...                ...
# 409                 2175934            29.4241           -98.4936
# 410                 2175934            29.4241           -98.4936
# 411                 2175934            29.4241           -98.4936
# 412                 2175934            29.4241           -98.4936
# 413                 2175934            29.4241           -98.4936
#
#     csaPrimaryCityZip csaTimeZone  csaStandardTimeUtcOffset  \
# 0               10001     Eastern                    -05:00
# 1               10001     Eastern                    -05:00
# 2               10001     Eastern                    -05:00
# 3               10001     Eastern                    -05:00
# 4               10001     Eastern                    -05:00
# ..                ...         ...                       ...
# 409             78205     Central                    -06:00
# 410             78205     Central                    -06:00
# 411             78205     Central                    -06:00
# 412             78205     Central                    -06:00
# 413             78205     Central                    -06:00
#
#      csaDaylightSavingsTimeUtcOffset  csaSearchLat  csaSearchLong  \
# 0                             -04:00       40.8419       -73.8359
# 1                             -04:00       40.8419       -73.8359
# 2                             -04:00       40.8419       -73.8359
# 3                             -04:00       40.8419       -73.8359
# 4                             -04:00       40.8419       -73.8359
# ..                               ...           ...            ...
# 409                           -05:00       29.4170       -98.4840
# 410                           -05:00       29.4170       -98.4840
# 411                           -05:00       29.4170       -98.4840
# 412                           -05:00       29.4170       -98.4840
# 413                           -05:00       29.4170       -98.4840
#
#     csaSearchRadius
# 0                25
# 1                25
# 2                25
# 3                25
# 4                25
# ..              ...
# 409              25
# 410              25
# 411              25
# 412              25
# 413              25
#
# [414 rows x 26 columns]

# %% [markdown]
# #### Set output data file filepath variable

# %%
output_data_filepath = "../output_data/"

# %% [markdown]
# #### Create variables to create the CSV file name

# %%
timestamp = dt.now().strftime("%Y%m%d_%H%M%S")
output_file_name = f"AirNowAPI_{timestamp}"
# print(output_file_name)

# %% [markdown]
# #### Convert & export DataFrame to CSV files

# %%
df.to_csv(f"{output_data_filepath}{output_file_name}.csv", encoding="utf-8", index= False)
