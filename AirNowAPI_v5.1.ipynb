# %% [markdown]
# #### Import Dependencies & needed API Keys

# %%
import pandas as pd
import requests
import datetime
from datetime import datetime as dt
from time import sleep

from config import airNowApiKeyShane, airNowApiKeyAudelia, airNowApiKeyCenez, airNowApiKeyJoseph, airNowApiKeyJoey
# from largest_combined_statistical_areas import largest_combined_statistical_areas
# from largest_combined_statistical_areas_v2_t25 import largest_combined_statistical_areas
from largest_combined_statistical_areas_v3_t25 import largest_combined_statistical_areas

# %%
largest_combined_statistical_areas
# Out:
# [{'csa_rank': 1,
#   'csa_name': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'primary_city': 'New York City',
#   'primary_city_state': 'NY',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 22679948, '2010_census': 22255491},
#   'primary_city_location': {'lat': 40.7128,
#    'long': -74.006,
#    'zip_code': '10001'},
#   'timezone_params': {'timezone': 'Eastern',
#    'utc_offset': {'standard_time': '-05:00',
#     'daylight_savings_time': '-04:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 40.8419,
#     'long': -73.8359,
#     'search_radius': 25}}},
#  {'csa_rank': 2,
#   'csa_name': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'primary_city': 'Los Angeles',
#   'primary_city_state': 'CA',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 18764814, '2010_census': 17877006},
#   'primary_city_location': {'lat': 34.0522,
#    'long': -118.2437,
#    'zip_code': '90001'},
#   'timezone_params': {'timezone': 'Pacific',
#    'utc_offset': {'standard_time': '-08:00',
#     'daylight_savings_time': '-07:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 33.9288,
#     'long': -118.2108,
#     'search_radius': 25}}},
#  {'csa_rank': 3,
#   'csa_name': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'primary_city': 'Chicago',
#   'primary_city_state': 'IL',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 9866910, '2010_census': 9840929},
#   'primary_city_location': {'lat': 41.8781,
#    'long': -87.6298,
#    'zip_code': '60601'},
#   'timezone_params': {'timezone': 'Central',
#    'utc_offset': {'standard_time': '-06:00',
#     'daylight_savings_time': '-05:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 41.964,
#     'long': -87.659,
#     'search_radius': 25}}},
#  {'csa_rank': 4,
#   'csa_name': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'primary_city': 'Washington',
#   'primary_city_state': 'DC',
#   'capital': 'yes',
#   'capital_of': 'United States',
#   'population': {'2018_estimate': 9778360, '2010_census': 9032651},
#   'primary_city_location': {'lat': 38.9072,
#    'long': -77.0369,
#    'zip_code': '20001'},
#   'timezone_params': {'timezone': 'Eastern',
#    'utc_offset': {'standard_time': '-05:00',
#     'daylight_savings_time': '-04:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 38.919,
#     'long': -77.013,
#     'search_radius': 25}}},
#  {'csa_rank': 5,
#   'csa_name': 'San Jose-San Francisco-Oakland, CA Combined Statistical Area',
#   'primary_city': 'San Francisco',
#   'primary_city_state': 'CA',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 9666055, '2010_census': 8923942},
#   'primary_city_location': {'lat': 37.7749,
#    'long': -122.4194,
#    'zip_code': '94102'},
#   'timezone_params': {'timezone': 'Pacific',
#    'utc_offset': {'standard_time': '-08:00',
#     'daylight_savings_time': '-07:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 37.75,
#     'long': -122.43,
#     'search_radius': 25}}},
#  {'csa_rank': 6,
#   'csa_name': 'Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area',
#   'primary_city': 'Boston',
#   'primary_city_state': 'MA',
#   'capital': 'yes',
#   'capital_of': 'Massachusetts',
#   'population': {'2018_estimate': 8285407, '2010_census': 7893376},
#   'primary_city_location': {'lat': 42.3601,
#    'long': -71.0589,
#    'zip_code': '02108'},
#   'timezone_params': {'timezone': 'Eastern',
#    'utc_offset': {'standard_time': '-05:00',
#     'daylight_savings_time': '-04:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 42.351,
#     'long': -71.051,
#     'search_radius': 25}}},
#  {'csa_rank': 7,
#   'csa_name': 'Dallas-Fort Worth, TX-OK Combined Statistical Area',
#   'primary_city': 'Dallas',
#   'primary_city_state': 'TX',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 7957493, '2010_census': 6816237},
#   'primary_city_location': {'lat': 32.7767,
#    'long': -96.797,
#    'zip_code': '75201'},
#   'timezone_params': {'timezone': 'Central',
#    'utc_offset': {'standard_time': '-06:00',
#     'daylight_savings_time': '-05:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 32.767,
#     'long': -96.783,
#     'search_radius': 25}}},
#  {'csa_rank': 8,
#   'csa_name': 'Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area',
#   'primary_city': 'Philadelphia',
#   'primary_city_state': 'PA',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 7204035, '2010_census': 7067807},
#   'primary_city_location': {'lat': 39.9526,
#    'long': -75.1652,
#    'zip_code': '19107'},
#   'timezone_params': {'timezone': 'Eastern',
#    'utc_offset': {'standard_time': '-05:00',
#     'daylight_savings_time': '-04:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 39.95,
#     'long': -75.151,
#     'search_radius': 25}}},
#  {'csa_rank': 9,
#   'csa_name': 'Houston-The Woodlands, TX Combined Statistical Area',
#   'primary_city': 'Houston',
#   'primary_city_state': 'TX',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 7197883, '2010_census': 6114562},
#   'primary_city_location': {'lat': 29.7604,
#    'long': -95.3698,
#    'zip_code': '77002'},
#   'timezone_params': {'timezone': 'Central',
#    'utc_offset': {'standard_time': '-06:00',
#     'daylight_savings_time': '-05:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 29.751,
#     'long': -95.351,
#     'search_radius': 25}}},
#  {'csa_rank': 10,
#   'csa_name': 'Miami-Port St. Lucie-Fort Lauderdale, FL Combined Statistical Area',
#   'primary_city': 'Miami',
#   'primary_city_state': 'FL',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 6913262, '2010_census': 6199860},
#   'primary_city_location': {'lat': 25.7617,
#    'long': -80.1918,
#    'zip_code': '33133'},
#   'timezone_params': {'timezone': 'Eastern',
#    'utc_offset': {'standard_time': '-05:00',
#     'daylight_savings_time': '-04:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 25.776,
#     'long': -80.211,
#     'search_radius': 25}}},
#  {'csa_rank': 11,
#   'csa_name': 'Atlanta–Athens-Clarke County–Sandy Springs, GA-AL Combined Statistical Area',
#   'primary_city': 'Atlanta',
#   'primary_city_state': 'GA',
#   'capital': 'yes',
#   'capital_of': 'Georgia',
#   'population': {'2018_estimate': 6775511, '2010_census': 6054858},
#   'primary_city_location': {'lat': 33.749,
#    'long': -84.388,
#    'zip_code': '30334'},
#   'timezone_params': {'timezone': 'Eastern',
#    'utc_offset': {'standard_time': '-05:00',
#     'daylight_savings_time': '-04:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 33.65,
#     'long': -84.43,
#     'search_radius': 25}}},
#  {'csa_rank': 12,
#   'csa_name': 'Detroit-Warren-Ann Arbor, MI Combined Statistical Area',
#   'primary_city': 'Detroit',
#   'primary_city_state': 'MI',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 5353002, '2010_census': 5318744},
#   'primary_city_location': {'lat': 42.3314,
#    'long': -83.0458,
#    'zip_code': '48226'},
#   'timezone_params': {'timezone': 'Eastern',
#    'utc_offset': {'standard_time': '-05:00',
#     'daylight_savings_time': '-04:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 42.233,
#     'long': -83.333,
#     'search_radius': 25}}},
#  {'csa_rank': 13,
#   'csa_name': 'Phoenix-Mesa, AZ Combined Statistical Area',
#   'primary_city': 'Phoenix',
#   'primary_city_state': 'AZ',
#   'capital': 'yes',
#   'capital_of': 'Arizona',
#   'population': {'2018_estimate': 4911851, '2010_census': 4246484},
#   'primary_city_location': {'lat': 33.4484,
#    'long': -112.074,
#    'zip_code': '85004'},
#   'timezone_params': {'timezone': 'Mountain',
#    'utc_offset': {'standard_time': '-07:00',
#     'daylight_savings_time': '-07:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 33.543,
#     'long': -112.071,
#     'search_radius': 25}}},
#  {'csa_rank': 14,
#   'csa_name': 'Seattle-Tacoma, WA Combined Statistical Area',
#   'primary_city': 'Seattle',
#   'primary_city_state': 'WA',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 4853364, '2010_census': 4274767},
#   'primary_city_location': {'lat': 47.6062,
#    'long': -122.3321,
#    'zip_code': '98164'},
#   'timezone_params': {'timezone': 'Pacific',
#    'utc_offset': {'standard_time': '-08:00',
#     'daylight_savings_time': '-07:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 47.562,
#     'long': -122.3405,
#     'search_radius': 25}}},
#  {'csa_rank': 15,
#   'csa_name': 'Orlando-Lakeland-Deltona, FL Combined Statistical Area',
#   'primary_city': 'Orlando',
#   'primary_city_state': 'FL',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 4096575, '2010_census': 3447946},
#   'primary_city_location': {'lat': 28.5383,
#    'long': -81.3792,
#    'zip_code': '32801'},
#   'timezone_params': {'timezone': 'Eastern',
#    'utc_offset': {'standard_time': '-05:00',
#     'daylight_savings_time': '-04:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 28.505,
#     'long': -81.374,
#     'search_radius': 25}}},
#  {'csa_rank': 16,
#   'csa_name': 'Minneapolis-St. Paul, MN-WI Combined Statistical Area',
#   'primary_city': 'Minneapolis',
#   'primary_city_state': 'MN',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 4014593, '2010_census': 3721504},
#   'primary_city_location': {'lat': 44.9778,
#    'long': -93.265,
#    'zip_code': '55415'},
#   'timezone_params': {'timezone': 'Central',
#    'utc_offset': {'standard_time': '-06:00',
#     'daylight_savings_time': '-05:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 44.955,
#     'long': -93.185,
#     'search_radius': 25}}},
#  {'csa_rank': 17,
#   'csa_name': 'Cleveland-Akron-Canton, OH Combined Statistical Area',
#   'primary_city': 'Cleveland',
#   'primary_city_state': 'OH',
#   'capital': 'xx',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 3599264, '2010_census': 3630166},
#   'primary_city_location': {'lat': 41.4993,
#    'long': -81.6944,
#    'zip_code': '44113'},
#   'timezone_params': {'timezone': 'Eastern',
#    'utc_offset': {'standard_time': '-05:00',
#     'daylight_savings_time': '-04:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 41.0814,
#     'long': -81.519,
#     'search_radius': 50}}},
#  {'csa_rank': 18,
#   'csa_name': 'Denver-Aurora, CO Combined Statistical Area',
#   'primary_city': 'Denver',
#   'primary_city_state': 'CO',
#   'capital': 'yes',
#   'capital_of': 'Colorado',
#   'population': {'2018_estimate': 3572798, '2010_census': 3090874},
#   'primary_city_location': {'lat': 39.7392,
#    'long': -104.9903,
#    'zip_code': '80202'},
#   'timezone_params': {'timezone': 'Mountain',
#    'utc_offset': {'standard_time': '-07:00',
#     'daylight_savings_time': '-06:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 39.768,
#     'long': -104.873,
#     'search_radius': 25}}},
#  {'csa_rank': 19,
#   'csa_name': 'Portland-Vancouver-Salem, OR-WA Combined Statistical Area',
#   'primary_city': 'Portland',
#   'primary_city_state': 'OR',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 3239335, '2010_census': 2921408},
#   'primary_city_location': {'lat': 45.5051,
#    'long': -122.675,
#    'zip_code': '97201'},
#   'timezone_params': {'timezone': 'Pacific',
#    'utc_offset': {'standard_time': '-08:00',
#     'daylight_savings_time': '-07:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 45.538,
#     'long': -122.656,
#     'search_radius': 25}}},
#  {'csa_rank': 20,
#   'csa_name': 'St. Louis-St. Charles-Farmington, MO-IL Combined Statistical Area',
#   'primary_city': 'St. Louis',
#   'primary_city_state': 'MO',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 2909777, '2010_census': 2892497},
#   'primary_city_location': {'lat': 38.627,
#    'long': -90.1994,
#    'zip_code': '63103'},
#   'timezone_params': {'timezone': 'Central',
#    'utc_offset': {'standard_time': '-06:00',
#     'daylight_savings_time': '-05:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 38.75,
#     'long': -90.383,
#     'search_radius': 25}}},
#  {'csa_rank': 21,
#   'csa_name': 'Charlotte-Concord, NC-SC Combined Statistical Area',
#   'primary_city': 'Charlotte',
#   'primary_city_state': 'NC',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 2753810, '2010_census': 2402623},
#   'primary_city_location': {'lat': 35.2271,
#    'long': -80.8431,
#    'zip_code': '28202'},
#   'timezone_params': {'timezone': 'Eastern',
#    'utc_offset': {'standard_time': '-05:00',
#     'daylight_savings_time': '-04:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 35.227,
#     'long': -80.843,
#     'search_radius': 25}}},
#  {'csa_rank': 22,
#   'csa_name': 'Sacramento-Roseville, CA Combined Statistical Area',
#   'primary_city': 'Sacramento',
#   'primary_city_state': 'CA',
#   'capital': 'yes',
#   'capital_of': 'California',
#   'population': {'2018_estimate': 2619754, '2010_census': 2414783},
#   'primary_city_location': {'lat': 38.5816,
#    'long': -121.4944,
#    'zip_code': '95814'},
#   'timezone_params': {'timezone': 'Pacific',
#    'utc_offset': {'standard_time': '-08:00',
#     'daylight_savings_time': '-07:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 38.567,
#     'long': -121.467,
#     'search_radius': 25}}},
#  {'csa_rank': 23,
#   'csa_name': 'Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area',
#   'primary_city': 'Pittsburgh',
#   'primary_city_state': 'PA',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 2612492, '2010_census': 2660727},
#   'primary_city_location': {'lat': 40.4406,
#    'long': -79.9959,
#    'zip_code': '15222'},
#   'timezone_params': {'timezone': 'Eastern',
#    'utc_offset': {'standard_time': '-05:00',
#     'daylight_savings_time': '-04:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 40.434,
#     'long': -79.984,
#     'search_radius': 25}}},
#  {'csa_rank': 24,
#   'csa_name': 'Salt Lake City-Provo-Orem, UT Combined Statistical Area',
#   'primary_city': 'Salt Lake City',
#   'primary_city_state': 'UT',
#   'capital': 'yes',
#   'capital_of': 'Utah',
#   'population': {'2018_estimate': 2606548, '2010_census': 2271696},
#   'primary_city_location': {'lat': 40.7608,
#    'long': -111.891,
#    'zip_code': '84101'},
#   'timezone_params': {'timezone': 'Mountain',
#    'utc_offset': {'standard_time': '-07:00',
#     'daylight_savings_time': '-06:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 40.777,
#     'long': -111.93,
#     'search_radius': 25}}},
#  {'csa_rank': 25,
#   'csa_name': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'primary_city': 'San Antonio',
#   'primary_city_state': 'TX',
#   'capital': 'no',
#   'capital_of': 'n/a',
#   'population': {'2018_estimate': 2555933, '2010_census': 2175934},
#   'primary_city_location': {'lat': 29.4241,
#    'long': -98.4936,
#    'zip_code': '78205'},
#   'timezone_params': {'timezone': 'Central',
#    'utc_offset': {'standard_time': '-06:00',
#     'daylight_savings_time': '-05:00'}},
#   'search_params': {'closest_monitoring_station': {'lat': 29.417,
#     'long': -98.484,
#     'search_radius': 25}}}]

# %% [markdown]
# #### Setup counters, empty list to hold data amd API Key Variables to be used

# %%
# Setup Counters
counterAttempts = 0
counterAttemptsPerAPI = 0
counterAPI = 1

# Setup empty list
apiData = []

# Setup API Key Variables
airNowApiKey1 = airNowApiKeyShane
airNowApiKey2 = airNowApiKeyAudelia
airNowApiKey3 = airNowApiKeyCenez
airNowApiKey4 = airNowApiKeyJoseph
airNowApiKey5 = airNowApiKeyJoey

# %% [markdown]
# #### Create a list of dates to iterate through (first 7 days of each month, 2015 to 2019)

# %%
# Set Date Range to use for API
# startDate = '2015-01-01'
startDate = '2020-04-07'
# endDate = '2019-12-31'
endDate = '2020-04-30'

# Create a list of dates (from Start to End)
dateList = pd.date_range(startDate, endDate).strftime("%Y-%m-%d").tolist()
# print(dateList)

# Create empty list to append dates within a given range to in for loop
datesToUseList = []

# Loop through dateList and append only dates that are within the range of days (of month) to the datesToUseList
for date in dateList:
    day = (datetime.datetime.strptime(date, "%Y-%m-%d")).day
    if day in range(1,8):
        datesToUseList.append(date)
#         print(f"KEEP: {date} is in range")
    else:
#         print(f"REMOVE: {date} is OUT OF RANGE")
        pass

# print(datesToUseList)
len(datesToUseList)
# Out:
# 1

# %% [markdown]
# #### Setup API Call Function and with URL, API Key, and variables to pass through in the requests.get() API call

# %%
def apiCallLatLongHistorical(csaRank, csaFullName, csaPrimaryCity, csaPrimaryCityState, csaPopulation2018Estimate, csaPopulation2010Census, csaPrimaryCityLat, csaPrimaryCityLong, csaPrimaryCityZip, csaTimeZone, csaStandardTimeUtcOffset, csaDaylightSavingsTimeUtcOffset, csaSearchLat, csaSearchLong, csaSearchRadius, obsDate, obsTime, apiKey, apiKeyUsed, counterAttempts, counterAttemptsPerAPI, counterAPI):
    
    # Empty response list variable every time function is called
    response = []
    
    # Set API Parameters to be passed through to API requests.get
    params = {}
#     params["baseURL"] = "http://www.airnowapi.org/aq/observation/latLong/historical/?format=application/json"
    params["baseURL"] = "http://www.airnowapi.org/aq/observation/zipCode/historical/?format=application/json"
    params["lat"] = f"{csaPrimaryCityLat}"
    params["long"] = f"{csaPrimaryCityLong}"
    params["zip"] = f"{csaPrimaryCityZip}"
    params["obsDate"] = f"{obsDate}"
    params["obsTime"] = "00-0000" # f"{obsTime}"
    params["searchDistance"] = f"{csaSearchRadius}" # "25"
    params["apiKey"] = apiKey


#     # Build API Request URL, passing through parameters - by LAT/LONG
#     requestURL = params["baseURL"] \
#                 + "&latitude=" + params["lat"] \
#                 + "&longitude=" + params["long"] \
#                 + "&date=" + params["obsDate"] \
#                 + "T" + params["obsTime"] \
#                 + "&distance=" + params["searchDistance"] \
#                 + "&API_KEY=" + params["apiKey"]
    
    # Build API Request URL, passing through parameters - by ZIP CODE
    requestURL = params["baseURL"] \
                + "&zipCode=" + params["zip"] \
                + "&date=" + params["obsDate"] \
                + "T" + params["obsTime"] \
                + "&distance=" + params["searchDistance"] \
                + "&API_KEY=" + params["apiKey"]

    
    # Logger: Print status message
    print("--------------------------------------------------")
    print("Requesting AirNow API Data for...")
    print("     **************************************************")
#     print(f"CITY: {cityName}, {cityState} | LAT: {params['lat']} | LONG: {params['long']} | DATE: {params['obsDate']} | TIME: {params['obsTime']}")
#     print(f"CITY: {cityName}, {cityState} | LAT: {params['lat']} | LONG: {params['long']} | DATE: {params['obsDate']}")
#     print(f"CSA: {csaFullName} | CITY: {csaPrimaryCity}, {csaPrimaryCityState} | LAT: {params['lat']} | LONG: {params['long']} | DATE: {params['obsDate']}")
    print(f"CSA: {csaFullName} | CITY: {csaPrimaryCity}, {csaPrimaryCityState} | ZIP: {params['zip']} | DATE: {params['obsDate']}")
    print(f"ATTEMPT:{counterAttempts} | ATTEMPT PER BATCH/API: {counterAttemptsPerAPI} | BATCH/API: {counterAPI} | API Key Used: {apiKeyUsed}")
    print("     **************************************************")
#     print(requestURL)
    
    # Set up error handling in the even there is an error in the API requests.get()
    try:
        
        # Execute requests.get, passing through built requestURL
        response = requests.get(requestURL).json()
        responseCode = requests.get(requestURL)
        
        print(f"Number of results found: {len(response)}")
        print("--------------------------------------------------")

        # Loop through response, appending each element (dictionary) as a new item in the apiData list
        for i in range(len(response)):
            
            # Break out the response "Category" Key value (another dictionary) into two separate values (to easily convert later to a csv, if needed)
            response[i]["AQICategoryNumber"] = response[i]["Category"]["Number"]
            response[i]["AQICategory"] = response[i]["Category"]["Name"]
            
            # Delete the "Category" Key value (another dictionary) from response since separate key: values were created and this is no longer needed
            del response[i]["Category"]
            
            # Add values brought in from the largest_combined_statistical_areas dictionary / json object to the response
            response[i]["csaRank"] = csaRank
            response[i]["csaFullName"] = csaFullName
            response[i]["csaPrimaryCity"] = csaPrimaryCity
            response[i]["csaPrimaryCityState"] = csaPrimaryCityState
            response[i]["csaPopulation2018Estimate"] = csaPopulation2018Estimate
            response[i]["csaPopulation2010Census"] = csaPopulation2010Census
            response[i]["csaPrimaryCityLat"] = csaPrimaryCityLat
            response[i]["csaPrimaryCityLong"] = csaPrimaryCityLong
            response[i]["csaPrimaryCityZip"] = csaPrimaryCityZip
          
            response[i]["csaTimeZone"] = csaTimeZone
            response[i]["csaStandardTimeUtcOffset"] = csaStandardTimeUtcOffset
            response[i]["csaDaylightSavingsTimeUtcOffset"] = csaDaylightSavingsTimeUtcOffset
            response[i]["csaSearchLat"] = csaSearchLat
            response[i]["csaSearchLong"] = csaSearchLong
            response[i]["csaSearchRadius"] = csaSearchRadius
          
            # Append the response to the apiData list
            apiData.append(response[i])

    except Exception as e:
#         print(f"ERROR: Unable to perform AirNow API request for CITY: {cityName}, {cityState}, LAT: {params['lat']}, LONG: {params['long']}, DATE: {params['obsDate']} & TIME: {params['obsTime']}.")
#         print(f"ERROR: Unable to perform AirNow API request for CITY: {cityName}, {cityState}, LAT: {params['lat']}, LONG: {params['long']}, DATE: {params['obsDate']} & TIME: {params['obsTime']}.")
#         print(f"ERROR: Unable to perform AirNow API request for CITY: CSA: {csaFullName} | CITY: {csaPrimaryCity}, {csaPrimaryCityState} | LAT: {params['lat']} | LONG: {params['long']} | DATE: {params['obsDate']}.")
        print(f"ERROR: Unable to perform AirNow API request for CITY: CSA: {csaFullName} | CITY: {csaPrimaryCity}, {csaPrimaryCityState} | ZIP: {params['zip']} | DATE: {params['obsDate']}.")
        print("%s" % e)
        print("--------------------------------------------------")
        pass
    
# if __name__ == "__apiCallLatLongHistorical__":
#     apiCallLatLongHistorical()

# %% [markdown]
# #### Loop through cities and dates, while updating variables and passing them through to the apiCallLatLongHistorical Function

# %%
# Loop through cities in the largest_combined_statistical_areas dictionary / json object
for csa in largest_combined_statistical_areas:
    
    # Loop through datesToUseList, calling the apiCallLatLongHistorical function, passing through variables    
    for date in datesToUseList:
    
        # Set varaiable values to pass into the apiCallLatLongHistorical function
        csaRank = csa["csa_rank"]
        csaFullName = csa["csa_name"]
        csaPrimaryCity = csa["primary_city"]
        csaPrimaryCityState = csa["primary_city_state"]
        csaPopulation2018Estimate = csa["population"]["2018_estimate"]
        csaPopulation2010Census = csa["population"]["2010_census"]
        csaPrimaryCityLat = csa["primary_city_location"]["lat"]
        csaPrimaryCityLong = csa["primary_city_location"]["long"]
        csaPrimaryCityZip = csa["primary_city_location"]["zip_code"]
        
        csaTimeZone = csa["timezone_params"]["timezone"]
        csaStandardTimeUtcOffset = csa["timezone_params"]["utc_offset"]["standard_time"]
        csaDaylightSavingsTimeUtcOffset = csa["timezone_params"]["utc_offset"]["daylight_savings_time"]
        csaSearchLat = csa["search_params"]["closest_monitoring_station"]["lat"]
        csaSearchLong = csa["search_params"]["closest_monitoring_station"]["long"]
        csaSearchRadius = csa["search_params"]["closest_monitoring_station"]["search_radius"]
        
        # Update overall attempt counter
        counterAttempts += 1
        
        # Once 250 attempts have been made for all five API Keys, reset counterAttemptsPerAPI, counterAPI and apiKey then sleep for one hour (3600 seconds)
        if counterAttemptsPerAPI >= 250 and counterAPI >= 5:
            counterAttemptsPerAPI = 1
            counterAPI = 1
            apiKey = airNowApiKey1
            print("*****  250 per API for all APIs avialable reached | RESET counterAttemptsPerAPI, counterAPI, apiKey & SLEEP  *****")
            sleep(3600)
#             sleep(3)

        # Once 250 attempts have been made for the currently used API Key, update counterAPI so a new apiKey is used next time through, reset counterAttemptsPerAPI
        elif counterAttemptsPerAPI >= 250:
            counterAPI += 1
            counterAttemptsPerAPI = 1
            print("*****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****")
            
        else:
            counterAttemptsPerAPI += 1

        # Set apiKey variable based on the counterAPI variable
        if counterAPI == 1:
            apiKey = airNowApiKey1
            apiKeyUsed = "airNowApiKey1"
        elif counterAPI == 2:
            apiKey = airNowApiKey2
            apiKeyUsed = "airNowApiKey2"
        elif counterAPI == 3:
            apiKey = airNowApiKey3
            apiKeyUsed = "airNowApiKey3"
        elif counterAPI == 4:
            apiKey = airNowApiKey4
            apiKeyUsed = "airNowApiKey4"
        elif counterAPI == 5:
            apiKey = airNowApiKey5
            apiKeyUsed = "airNowApiKey5"
        
        # Call the apiCallLatLongHistorical function, passing through updated variables as parameters
        apiCallLatLongHistorical(csaRank, csaFullName, csaPrimaryCity, csaPrimaryCityState, csaPopulation2018Estimate, csaPopulation2010Census, csaPrimaryCityLat, csaPrimaryCityLong, csaPrimaryCityZip, csaTimeZone, csaStandardTimeUtcOffset, csaDaylightSavingsTimeUtcOffset, csaSearchLat, csaSearchLong, csaSearchRadius, date, "00-0000", apiKey, apiKeyUsed, counterAttempts, counterAttemptsPerAPI, counterAPI)
# Out:
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: New York-Newark, NY-NJ-CT-PA Combined Statistical Area | CITY: New York City, NY | ZIP: 10001 | DATE: 2020-04-07
# ATTEMPT:26 | ATTEMPT PER BATCH/API: 26 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 3
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Los Angeles-Long Beach, CA Combined Statistical Area | CITY: Los Angeles, CA | ZIP: 90001 | DATE: 2020-04-07
# ATTEMPT:27 | ATTEMPT PER BATCH/API: 27 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Chicago-Naperville, IL-IN-WI Combined Statistical Area | CITY: Chicago, IL | ZIP: 60601 | DATE: 2020-04-07
# ATTEMPT:28 | ATTEMPT PER BATCH/API: 28 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area | CITY: Washington, DC | ZIP: 20001 | DATE: 2020-04-07
# ATTEMPT:29 | ATTEMPT PER BATCH/API: 29 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 3
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: San Jose-San Francisco-Oakland, CA Combined Statistical Area | CITY: San Francisco, CA | ZIP: 94102 | DATE: 2020-04-07
# ATTEMPT:30 | ATTEMPT PER BATCH/API: 30 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area | CITY: Boston, MA | ZIP: 02108 | DATE: 2020-04-07
# ATTEMPT:31 | ATTEMPT PER BATCH/API: 31 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Dallas-Fort Worth, TX-OK Combined Statistical Area | CITY: Dallas, TX | ZIP: 75201 | DATE: 2020-04-07
# ATTEMPT:32 | ATTEMPT PER BATCH/API: 32 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area | CITY: Philadelphia, PA | ZIP: 19107 | DATE: 2020-04-07
# ATTEMPT:33 | ATTEMPT PER BATCH/API: 33 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 3
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Houston-The Woodlands, TX Combined Statistical Area | CITY: Houston, TX | ZIP: 77002 | DATE: 2020-04-07
# ATTEMPT:34 | ATTEMPT PER BATCH/API: 34 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Miami-Port St. Lucie-Fort Lauderdale, FL Combined Statistical Area | CITY: Miami, FL | ZIP: 33133 | DATE: 2020-04-07
# ATTEMPT:35 | ATTEMPT PER BATCH/API: 35 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Atlanta–Athens-Clarke County–Sandy Springs, GA-AL Combined Statistical Area | CITY: Atlanta, GA | ZIP: 30334 | DATE: 2020-04-07
# ATTEMPT:36 | ATTEMPT PER BATCH/API: 36 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 3
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Detroit-Warren-Ann Arbor, MI Combined Statistical Area | CITY: Detroit, MI | ZIP: 48226 | DATE: 2020-04-07
# ATTEMPT:37 | ATTEMPT PER BATCH/API: 37 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 3
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Phoenix-Mesa, AZ Combined Statistical Area | CITY: Phoenix, AZ | ZIP: 85004 | DATE: 2020-04-07
# ATTEMPT:38 | ATTEMPT PER BATCH/API: 38 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 3
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Seattle-Tacoma, WA Combined Statistical Area | CITY: Seattle, WA | ZIP: 98164 | DATE: 2020-04-07
# ATTEMPT:39 | ATTEMPT PER BATCH/API: 39 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Orlando-Lakeland-Deltona, FL Combined Statistical Area | CITY: Orlando, FL | ZIP: 32801 | DATE: 2020-04-07
# ATTEMPT:40 | ATTEMPT PER BATCH/API: 40 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Minneapolis-St. Paul, MN-WI Combined Statistical Area | CITY: Minneapolis, MN | ZIP: 55415 | DATE: 2020-04-07
# ATTEMPT:41 | ATTEMPT PER BATCH/API: 41 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Cleveland-Akron-Canton, OH Combined Statistical Area | CITY: Cleveland, OH | ZIP: 44113 | DATE: 2020-04-07
# ATTEMPT:42 | ATTEMPT PER BATCH/API: 42 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 3
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Denver-Aurora, CO Combined Statistical Area | CITY: Denver, CO | ZIP: 80202 | DATE: 2020-04-07
# ATTEMPT:43 | ATTEMPT PER BATCH/API: 43 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 3
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Portland-Vancouver-Salem, OR-WA Combined Statistical Area | CITY: Portland, OR | ZIP: 97201 | DATE: 2020-04-07
# ATTEMPT:44 | ATTEMPT PER BATCH/API: 44 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: St. Louis-St. Charles-Farmington, MO-IL Combined Statistical Area | CITY: St. Louis, MO | ZIP: 63103 | DATE: 2020-04-07
# ATTEMPT:45 | ATTEMPT PER BATCH/API: 45 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 3
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Charlotte-Concord, NC-SC Combined Statistical Area | CITY: Charlotte, NC | ZIP: 28202 | DATE: 2020-04-07
# ATTEMPT:46 | ATTEMPT PER BATCH/API: 46 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Sacramento-Roseville, CA Combined Statistical Area | CITY: Sacramento, CA | ZIP: 95814 | DATE: 2020-04-07
# ATTEMPT:47 | ATTEMPT PER BATCH/API: 47 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 3
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area | CITY: Pittsburgh, PA | ZIP: 15222 | DATE: 2020-04-07
# ATTEMPT:48 | ATTEMPT PER BATCH/API: 48 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: Salt Lake City-Provo-Orem, UT Combined Statistical Area | CITY: Salt Lake City, UT | ZIP: 84101 | DATE: 2020-04-07
# ATTEMPT:49 | ATTEMPT PER BATCH/API: 49 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CSA: San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area | CITY: San Antonio, TX | ZIP: 78205 | DATE: 2020-04-07
# ATTEMPT:50 | ATTEMPT PER BATCH/API: 50 | BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------

# %% [markdown]
# #### Check the number of records in the apiData list

# %%
# apiData
len(apiData)
# Out:
# 59

# %% [markdown]
# #### Create DataFrame holding the values from teh apiData list

# %%
df = pd.DataFrame(apiData)

# Visualize the DataFrame
df
# Out:
#    DateObserved  HourObserved LocalTimeZone                 ReportingArea  \
# 0   2020-04-07              0           EST          New York City Region
# 1   2020-04-07              0           EST          New York City Region
# 2   2020-04-07              0           EST          New York City Region
# 3   2020-04-07              0           PST               S Central LA CO
# 4   2020-04-07              0           CST                       Chicago
# 5   2020-04-07              0           CST                       Chicago
# 6   2020-04-07              0           EST       Metropolitan Washington
# 7   2020-04-07              0           EST       Metropolitan Washington
# 8   2020-04-07              0           EST       Metropolitan Washington
# 9   2020-04-07              0           PST                 San Francisco
# 10  2020-04-07              0           PST                 San Francisco
# 11  2020-04-07              0           EST                        Boston
# 12  2020-04-07              0           EST                        Boston
# 13  2020-04-07              0           CST             Dallas-Fort Worth
# 14  2020-04-07              0           CST             Dallas-Fort Worth
# 15  2020-04-07              0           EST                  Philadelphia
# 16  2020-04-07              0           EST                  Philadelphia
# 17  2020-04-07              0           EST                  Philadelphia
# 18  2020-04-07              0           CST    Houston-Galveston-Brazoria
# 19  2020-04-07              0           CST    Houston-Galveston-Brazoria
# 20  2020-04-07              0           EST                         Miami
# 21  2020-04-07              0           EST                         Miami
# 22  2020-04-07              0           EST                       Atlanta
# 23  2020-04-07              0           EST                       Atlanta
# 24  2020-04-07              0           EST                       Atlanta
# 25  2020-04-07              0           EST                       Detroit
# 26  2020-04-07              0           EST                       Detroit
# 27  2020-04-07              0           EST                       Detroit
# 28  2020-04-07              0           MST                       Phoenix
# 29  2020-04-07              0           MST                       Phoenix
# 30  2020-04-07              0           MST                       Phoenix
# 31  2020-04-07              0           PST  Seattle-Bellevue-Kent Valley
# 32  2020-04-07              0           PST  Seattle-Bellevue-Kent Valley
# 33  2020-04-07              0           EST                       Orlando
# 34  2020-04-07              0           EST                       Orlando
# 35  2020-04-07              0           CST          Minneapolis-St. Paul
# 36  2020-04-07              0           CST          Minneapolis-St. Paul
# 37  2020-04-07              0           EST        Cleveland-Akron-Lorain
# 38  2020-04-07              0           EST        Cleveland-Akron-Lorain
# 39  2020-04-07              0           EST        Cleveland-Akron-Lorain
# 40  2020-04-07              0           MST                Denver/Boulder
# 41  2020-04-07              0           MST                Denver/Boulder
# 42  2020-04-07              0           MST                Denver/Boulder
# 43  2020-04-07              0           PST                      Portland
# 44  2020-04-07              0           PST                      Portland
# 45  2020-04-07              0           CST                   Saint Louis
# 46  2020-04-07              0           CST                   Saint Louis
# 47  2020-04-07              0           CST                   Saint Louis
# 48  2020-04-07              0           EST            Mecklenburg County
# 49  2020-04-07              0           EST            Mecklenburg County
# 50  2020-04-07              0           PST                    Sacramento
# 51  2020-04-07              0           PST                    Sacramento
# 52  2020-04-07              0           PST                    Sacramento
# 53  2020-04-07              0           EST                    Pittsburgh
# 54  2020-04-07              0           EST                    Pittsburgh
# 55  2020-04-07              0           MST                Salt Lake City
# 56  2020-04-07              0           MST                Salt Lake City
# 57  2020-04-07              0           CST                   San Antonio
# 58  2020-04-07              0           CST                   San Antonio
#
#    StateCode  Latitude  Longitude ParameterName  AQI  AQICategoryNumber  ...  \
# 0         NY   40.8419   -73.8359         OZONE   47                  1  ...
# 1         NY   40.8419   -73.8359         PM2.5   22                  1  ...
# 2         NY   40.8419   -73.8359          PM10   14                  1  ...
# 3         CA   33.9288  -118.2108         OZONE   31                  1  ...
# 4         IL   41.9640   -87.6590         OZONE   43                  1  ...
# 5         IL   41.9640   -87.6590         PM2.5   56                  2  ...
# 6         DC   38.9190   -77.0130         OZONE   42                  1  ...
# 7         DC   38.9190   -77.0130         PM2.5   40                  1  ...
# 8         DC   38.9190   -77.0130          PM10   17                  1  ...
# 9         CA   37.7500  -122.4300         OZONE   36                  1  ...
# 10        CA   37.7500  -122.4300         PM2.5   23                  1  ...
# 11        MA   42.3510   -71.0510         OZONE   39                  1  ...
# 12        MA   42.3510   -71.0510         PM2.5   12                  1  ...
# 13        TX   32.7670   -96.7830         OZONE   44                  1  ...
# 14        TX   32.7670   -96.7830         PM2.5   52                  2  ...
# 15        PA   39.9500   -75.1510         OZONE   45                  1  ...
# 16        PA   39.9500   -75.1510         PM2.5   58                  2  ...
# 17        PA   39.9500   -75.1510          PM10   22                  1  ...
# 18        TX   29.7510   -95.3510         OZONE   29                  1  ...
# 19        TX   29.7510   -95.3510         PM2.5   56                  2  ...
# 20        FL   25.7760   -80.2110         OZONE   36                  1  ...
# 21        FL   25.7760   -80.2110         PM2.5   31                  1  ...
# 22        GA   33.6500   -84.4300         OZONE   40                  1  ...
# 23        GA   33.6500   -84.4300         PM2.5   76                  2  ...
# 24        GA   33.6500   -84.4300          PM10   24                  1  ...
# 25        MI   42.2330   -83.3330         OZONE   36                  1  ...
# 26        MI   42.2330   -83.3330         PM2.5   53                  2  ...
# 27        MI   42.2330   -83.3330          PM10   18                  1  ...
# 28        AZ   33.5430  -112.0710         OZONE   46                  1  ...
# 29        AZ   33.5430  -112.0710         PM2.5   21                  1  ...
# 30        AZ   33.5430  -112.0710          PM10   43                  1  ...
# 31        WA   47.5620  -122.3405         OZONE   31                  1  ...
# 32        WA   47.5620  -122.3405         PM2.5   39                  1  ...
# 33        FL   28.5050   -81.3740         OZONE   46                  1  ...
# 34        FL   28.5050   -81.3740         PM2.5   13                  1  ...
# 35        MN   44.9550   -93.1850         OZONE   15                  1  ...
# 36        MN   44.9550   -93.1850         PM2.5   60                  2  ...
# 37        OH   41.0814   -81.5190         OZONE   43                  1  ...
# 38        OH   41.0814   -81.5190         PM2.5   55                  2  ...
# 39        OH   41.0814   -81.5190          PM10   31                  1  ...
# 40        CO   39.7680  -104.8730         OZONE   64                  2  ...
# 41        CO   39.7680  -104.8730         PM2.5   26                  1  ...
# 42        CO   39.7680  -104.8730          PM10   33                  1  ...
# 43        OR   45.5380  -122.6560         OZONE   41                  1  ...
# 44        OR   45.5380  -122.6560         PM2.5   20                  1  ...
# 45        MO   38.7500   -90.3830         OZONE   39                  1  ...
# 46        MO   38.7500   -90.3830         PM2.5   40                  1  ...
# 47        MO   38.7500   -90.3830          PM10   40                  1  ...
# 48        NC   35.2270   -80.8430         OZONE   46                  1  ...
# 49        NC   35.2270   -80.8430         PM2.5   48                  1  ...
# 50        CA   38.5670  -121.4670         OZONE   36                  1  ...
# 51        CA   38.5670  -121.4670         PM2.5   14                  1  ...
# 52        CA   38.5670  -121.4670          PM10    7                  1  ...
# 53        PA   40.4340   -79.9840         OZONE   40                  1  ...
# 54        PA   40.4340   -79.9840         PM2.5   46                  1  ...
# 55        UT   40.7770  -111.9300         OZONE   43                  1  ...
# 56        UT   40.7770  -111.9300         PM2.5   25                  1  ...
# 57        TX   29.4170   -98.4840         OZONE   29                  1  ...
# 58        TX   29.4170   -98.4840         PM2.5   58                  2  ...
#
#    csaPopulation2010Census  csaPrimaryCityLat csaPrimaryCityLong  \
# 0                 22255491            40.7128           -74.0060
# 1                 22255491            40.7128           -74.0060
# 2                 22255491            40.7128           -74.0060
# 3                 17877006            34.0522          -118.2437
# 4                  9840929            41.8781           -87.6298
# 5                  9840929            41.8781           -87.6298
# 6                  9032651            38.9072           -77.0369
# 7                  9032651            38.9072           -77.0369
# 8                  9032651            38.9072           -77.0369
# 9                  8923942            37.7749          -122.4194
# 10                 8923942            37.7749          -122.4194
# 11                 7893376            42.3601           -71.0589
# 12                 7893376            42.3601           -71.0589
# 13                 6816237            32.7767           -96.7970
# 14                 6816237            32.7767           -96.7970
# 15                 7067807            39.9526           -75.1652
# 16                 7067807            39.9526           -75.1652
# 17                 7067807            39.9526           -75.1652
# 18                 6114562            29.7604           -95.3698
# 19                 6114562            29.7604           -95.3698
# 20                 6199860            25.7617           -80.1918
# 21                 6199860            25.7617           -80.1918
# 22                 6054858            33.7490           -84.3880
# 23                 6054858            33.7490           -84.3880
# 24                 6054858            33.7490           -84.3880
# 25                 5318744            42.3314           -83.0458
# 26                 5318744            42.3314           -83.0458
# 27                 5318744            42.3314           -83.0458
# 28                 4246484            33.4484          -112.0740
# 29                 4246484            33.4484          -112.0740
# 30                 4246484            33.4484          -112.0740
# 31                 4274767            47.6062          -122.3321
# 32                 4274767            47.6062          -122.3321
# 33                 3447946            28.5383           -81.3792
# 34                 3447946            28.5383           -81.3792
# 35                 3721504            44.9778           -93.2650
# 36                 3721504            44.9778           -93.2650
# 37                 3630166            41.4993           -81.6944
# 38                 3630166            41.4993           -81.6944
# 39                 3630166            41.4993           -81.6944
# 40                 3090874            39.7392          -104.9903
# 41                 3090874            39.7392          -104.9903
# 42                 3090874            39.7392          -104.9903
# 43                 2921408            45.5051          -122.6750
# 44                 2921408            45.5051          -122.6750
# 45                 2892497            38.6270           -90.1994
# 46                 2892497            38.6270           -90.1994
# 47                 2892497            38.6270           -90.1994
# 48                 2402623            35.2271           -80.8431
# 49                 2402623            35.2271           -80.8431
# 50                 2414783            38.5816          -121.4944
# 51                 2414783            38.5816          -121.4944
# 52                 2414783            38.5816          -121.4944
# 53                 2660727            40.4406           -79.9959
# 54                 2660727            40.4406           -79.9959
# 55                 2271696            40.7608          -111.8910
# 56                 2271696            40.7608          -111.8910
# 57                 2175934            29.4241           -98.4936
# 58                 2175934            29.4241           -98.4936
#
#    csaPrimaryCityZip csaTimeZone  csaStandardTimeUtcOffset  \
# 0              10001     Eastern                    -05:00
# 1              10001     Eastern                    -05:00
# 2              10001     Eastern                    -05:00
# 3              90001     Pacific                    -08:00
# 4              60601     Central                    -06:00
# 5              60601     Central                    -06:00
# 6              20001     Eastern                    -05:00
# 7              20001     Eastern                    -05:00
# 8              20001     Eastern                    -05:00
# 9              94102     Pacific                    -08:00
# 10             94102     Pacific                    -08:00
# 11             02108     Eastern                    -05:00
# 12             02108     Eastern                    -05:00
# 13             75201     Central                    -06:00
# 14             75201     Central                    -06:00
# 15             19107     Eastern                    -05:00
# 16             19107     Eastern                    -05:00
# 17             19107     Eastern                    -05:00
# 18             77002     Central                    -06:00
# 19             77002     Central                    -06:00
# 20             33133     Eastern                    -05:00
# 21             33133     Eastern                    -05:00
# 22             30334     Eastern                    -05:00
# 23             30334     Eastern                    -05:00
# 24             30334     Eastern                    -05:00
# 25             48226     Eastern                    -05:00
# 26             48226     Eastern                    -05:00
# 27             48226     Eastern                    -05:00
# 28             85004    Mountain                    -07:00
# 29             85004    Mountain                    -07:00
# 30             85004    Mountain                    -07:00
# 31             98164     Pacific                    -08:00
# 32             98164     Pacific                    -08:00
# 33             32801     Eastern                    -05:00
# 34             32801     Eastern                    -05:00
# 35             55415     Central                    -06:00
# 36             55415     Central                    -06:00
# 37             44113     Eastern                    -05:00
# 38             44113     Eastern                    -05:00
# 39             44113     Eastern                    -05:00
# 40             80202    Mountain                    -07:00
# 41             80202    Mountain                    -07:00
# 42             80202    Mountain                    -07:00
# 43             97201     Pacific                    -08:00
# 44             97201     Pacific                    -08:00
# 45             63103     Central                    -06:00
# 46             63103     Central                    -06:00
# 47             63103     Central                    -06:00
# 48             28202     Eastern                    -05:00
# 49             28202     Eastern                    -05:00
# 50             95814     Pacific                    -08:00
# 51             95814     Pacific                    -08:00
# 52             95814     Pacific                    -08:00
# 53             15222     Eastern                    -05:00
# 54             15222     Eastern                    -05:00
# 55             84101    Mountain                    -07:00
# 56             84101    Mountain                    -07:00
# 57             78205     Central                    -06:00
# 58             78205     Central                    -06:00
#
#     csaDaylightSavingsTimeUtcOffset  csaSearchLat  csaSearchLong  \
# 0                            -04:00       40.8419       -73.8359
# 1                            -04:00       40.8419       -73.8359
# 2                            -04:00       40.8419       -73.8359
# 3                            -07:00       33.9288      -118.2108
# 4                            -05:00       41.9640       -87.6590
# 5                            -05:00       41.9640       -87.6590
# 6                            -04:00       38.9190       -77.0130
# 7                            -04:00       38.9190       -77.0130
# 8                            -04:00       38.9190       -77.0130
# 9                            -07:00       37.7500      -122.4300
# 10                           -07:00       37.7500      -122.4300
# 11                           -04:00       42.3510       -71.0510
# 12                           -04:00       42.3510       -71.0510
# 13                           -05:00       32.7670       -96.7830
# 14                           -05:00       32.7670       -96.7830
# 15                           -04:00       39.9500       -75.1510
# 16                           -04:00       39.9500       -75.1510
# 17                           -04:00       39.9500       -75.1510
# 18                           -05:00       29.7510       -95.3510
# 19                           -05:00       29.7510       -95.3510
# 20                           -04:00       25.7760       -80.2110
# 21                           -04:00       25.7760       -80.2110
# 22                           -04:00       33.6500       -84.4300
# 23                           -04:00       33.6500       -84.4300
# 24                           -04:00       33.6500       -84.4300
# 25                           -04:00       42.2330       -83.3330
# 26                           -04:00       42.2330       -83.3330
# 27                           -04:00       42.2330       -83.3330
# 28                           -07:00       33.5430      -112.0710
# 29                           -07:00       33.5430      -112.0710
# 30                           -07:00       33.5430      -112.0710
# 31                           -07:00       47.5620      -122.3405
# 32                           -07:00       47.5620      -122.3405
# 33                           -04:00       28.5050       -81.3740
# 34                           -04:00       28.5050       -81.3740
# 35                           -05:00       44.9550       -93.1850
# 36                           -05:00       44.9550       -93.1850
# 37                           -04:00       41.0814       -81.5190
# 38                           -04:00       41.0814       -81.5190
# 39                           -04:00       41.0814       -81.5190
# 40                           -06:00       39.7680      -104.8730
# 41                           -06:00       39.7680      -104.8730
# 42                           -06:00       39.7680      -104.8730
# 43                           -07:00       45.5380      -122.6560
# 44                           -07:00       45.5380      -122.6560
# 45                           -05:00       38.7500       -90.3830
# 46                           -05:00       38.7500       -90.3830
# 47                           -05:00       38.7500       -90.3830
# 48                           -04:00       35.2270       -80.8430
# 49                           -04:00       35.2270       -80.8430
# 50                           -07:00       38.5670      -121.4670
# 51                           -07:00       38.5670      -121.4670
# 52                           -07:00       38.5670      -121.4670
# 53                           -04:00       40.4340       -79.9840
# 54                           -04:00       40.4340       -79.9840
# 55                           -06:00       40.7770      -111.9300
# 56                           -06:00       40.7770      -111.9300
# 57                           -05:00       29.4170       -98.4840
# 58                           -05:00       29.4170       -98.4840
#
#    csaSearchRadius
# 0               25
# 1               25
# 2               25
# 3               25
# 4               25
# 5               25
# 6               25
# 7               25
# 8               25
# 9               25
# 10              25
# 11              25
# 12              25
# 13              25
# 14              25
# 15              25
# 16              25
# 17              25
# 18              25
# 19              25
# 20              25
# 21              25
# 22              25
# 23              25
# 24              25
# 25              25
# 26              25
# 27              25
# 28              25
# 29              25
# 30              25
# 31              25
# 32              25
# 33              25
# 34              25
# 35              25
# 36              25
# 37              50
# 38              50
# 39              50
# 40              25
# 41              25
# 42              25
# 43              25
# 44              25
# 45              25
# 46              25
# 47              25
# 48              25
# 49              25
# 50              25
# 51              25
# 52              25
# 53              25
# 54              25
# 55              25
# 56              25
# 57              25
# 58              25
#
# [59 rows x 26 columns]

# %% [markdown]
# #### Set output data file filepath variable

# %%
output_data_filepath = "output_data/"

# %% [markdown]
# #### Create variables to create the CSV file name

# %%
timestamp = dt.now().strftime("%Y%m%d_%H%M%S")
output_file_name = f"AirNowAPI_{timestamp}"
# print(output_file_name)

# %% [markdown]
# #### Convert & export DataFrame to CSV and JSON files

# %%
df.to_csv(f"{output_data_filepath}{output_file_name}.csv", encoding="utf-8", index= False)

# %%
# df.to_json(f"{output_data_filepath}{output_file_name}.json")

# %%
apiData
# Out:
# [{'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'New York City Region',
#   'StateCode': 'NY',
#   'Latitude': 40.8419,
#   'Longitude': -73.8359,
#   'ParameterName': 'OZONE',
#   'AQI': 47,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'New York City Region',
#   'StateCode': 'NY',
#   'Latitude': 40.8419,
#   'Longitude': -73.8359,
#   'ParameterName': 'PM2.5',
#   'AQI': 22,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'New York City Region',
#   'StateCode': 'NY',
#   'Latitude': 40.8419,
#   'Longitude': -73.8359,
#   'ParameterName': 'PM10',
#   'AQI': 14,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 1,
#   'csaFullName': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'csaPrimaryCity': 'New York City',
#   'csaPrimaryCityState': 'NY',
#   'csaPopulation2018Estimate': 22679948,
#   'csaPopulation2010Census': 22255491,
#   'csaPrimaryCityLat': 40.7128,
#   'csaPrimaryCityLong': -74.006,
#   'csaPrimaryCityZip': '10001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.8419,
#   'csaSearchLong': -73.8359,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'S Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 33.9288,
#   'Longitude': -118.2108,
#   'ParameterName': 'OZONE',
#   'AQI': 31,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 2,
#   'csaFullName': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Los Angeles',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 18764814,
#   'csaPopulation2010Census': 17877006,
#   'csaPrimaryCityLat': 34.0522,
#   'csaPrimaryCityLong': -118.2437,
#   'csaPrimaryCityZip': '90001',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.9288,
#   'csaSearchLong': -118.2108,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'OZONE',
#   'AQI': 43,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'PM2.5',
#   'AQI': 56,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 3,
#   'csaFullName': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Chicago',
#   'csaPrimaryCityState': 'IL',
#   'csaPopulation2018Estimate': 9866910,
#   'csaPopulation2010Census': 9840929,
#   'csaPrimaryCityLat': 41.8781,
#   'csaPrimaryCityLong': -87.6298,
#   'csaPrimaryCityZip': '60601',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 41.964,
#   'csaSearchLong': -87.659,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'OZONE',
#   'AQI': 42,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM2.5',
#   'AQI': 40,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM10',
#   'AQI': 17,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 4,
#   'csaFullName': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'csaPrimaryCity': 'Washington',
#   'csaPrimaryCityState': 'DC',
#   'csaPopulation2018Estimate': 9778360,
#   'csaPopulation2010Census': 9032651,
#   'csaPrimaryCityLat': 38.9072,
#   'csaPrimaryCityLong': -77.0369,
#   'csaPrimaryCityZip': '20001',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 38.919,
#   'csaSearchLong': -77.013,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'San Francisco',
#   'StateCode': 'CA',
#   'Latitude': 37.75,
#   'Longitude': -122.43,
#   'ParameterName': 'OZONE',
#   'AQI': 36,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 5,
#   'csaFullName': 'San Jose-San Francisco-Oakland, CA Combined Statistical Area',
#   'csaPrimaryCity': 'San Francisco',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 9666055,
#   'csaPopulation2010Census': 8923942,
#   'csaPrimaryCityLat': 37.7749,
#   'csaPrimaryCityLong': -122.4194,
#   'csaPrimaryCityZip': '94102',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 37.75,
#   'csaSearchLong': -122.43,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'San Francisco',
#   'StateCode': 'CA',
#   'Latitude': 37.75,
#   'Longitude': -122.43,
#   'ParameterName': 'PM2.5',
#   'AQI': 23,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 5,
#   'csaFullName': 'San Jose-San Francisco-Oakland, CA Combined Statistical Area',
#   'csaPrimaryCity': 'San Francisco',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 9666055,
#   'csaPopulation2010Census': 8923942,
#   'csaPrimaryCityLat': 37.7749,
#   'csaPrimaryCityLong': -122.4194,
#   'csaPrimaryCityZip': '94102',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 37.75,
#   'csaSearchLong': -122.43,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Boston',
#   'StateCode': 'MA',
#   'Latitude': 42.351,
#   'Longitude': -71.051,
#   'ParameterName': 'OZONE',
#   'AQI': 39,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 6,
#   'csaFullName': 'Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area',
#   'csaPrimaryCity': 'Boston',
#   'csaPrimaryCityState': 'MA',
#   'csaPopulation2018Estimate': 8285407,
#   'csaPopulation2010Census': 7893376,
#   'csaPrimaryCityLat': 42.3601,
#   'csaPrimaryCityLong': -71.0589,
#   'csaPrimaryCityZip': '02108',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 42.351,
#   'csaSearchLong': -71.051,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Boston',
#   'StateCode': 'MA',
#   'Latitude': 42.351,
#   'Longitude': -71.051,
#   'ParameterName': 'PM2.5',
#   'AQI': 12,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 6,
#   'csaFullName': 'Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area',
#   'csaPrimaryCity': 'Boston',
#   'csaPrimaryCityState': 'MA',
#   'csaPopulation2018Estimate': 8285407,
#   'csaPopulation2010Census': 7893376,
#   'csaPrimaryCityLat': 42.3601,
#   'csaPrimaryCityLong': -71.0589,
#   'csaPrimaryCityZip': '02108',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 42.351,
#   'csaSearchLong': -71.051,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Dallas-Fort Worth',
#   'StateCode': 'TX',
#   'Latitude': 32.767,
#   'Longitude': -96.783,
#   'ParameterName': 'OZONE',
#   'AQI': 44,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 7,
#   'csaFullName': 'Dallas-Fort Worth, TX-OK Combined Statistical Area',
#   'csaPrimaryCity': 'Dallas',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 7957493,
#   'csaPopulation2010Census': 6816237,
#   'csaPrimaryCityLat': 32.7767,
#   'csaPrimaryCityLong': -96.797,
#   'csaPrimaryCityZip': '75201',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 32.767,
#   'csaSearchLong': -96.783,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Dallas-Fort Worth',
#   'StateCode': 'TX',
#   'Latitude': 32.767,
#   'Longitude': -96.783,
#   'ParameterName': 'PM2.5',
#   'AQI': 52,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 7,
#   'csaFullName': 'Dallas-Fort Worth, TX-OK Combined Statistical Area',
#   'csaPrimaryCity': 'Dallas',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 7957493,
#   'csaPopulation2010Census': 6816237,
#   'csaPrimaryCityLat': 32.7767,
#   'csaPrimaryCityLong': -96.797,
#   'csaPrimaryCityZip': '75201',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 32.767,
#   'csaSearchLong': -96.783,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Philadelphia',
#   'StateCode': 'PA',
#   'Latitude': 39.95,
#   'Longitude': -75.151,
#   'ParameterName': 'OZONE',
#   'AQI': 45,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 8,
#   'csaFullName': 'Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area',
#   'csaPrimaryCity': 'Philadelphia',
#   'csaPrimaryCityState': 'PA',
#   'csaPopulation2018Estimate': 7204035,
#   'csaPopulation2010Census': 7067807,
#   'csaPrimaryCityLat': 39.9526,
#   'csaPrimaryCityLong': -75.1652,
#   'csaPrimaryCityZip': '19107',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 39.95,
#   'csaSearchLong': -75.151,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Philadelphia',
#   'StateCode': 'PA',
#   'Latitude': 39.95,
#   'Longitude': -75.151,
#   'ParameterName': 'PM2.5',
#   'AQI': 58,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 8,
#   'csaFullName': 'Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area',
#   'csaPrimaryCity': 'Philadelphia',
#   'csaPrimaryCityState': 'PA',
#   'csaPopulation2018Estimate': 7204035,
#   'csaPopulation2010Census': 7067807,
#   'csaPrimaryCityLat': 39.9526,
#   'csaPrimaryCityLong': -75.1652,
#   'csaPrimaryCityZip': '19107',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 39.95,
#   'csaSearchLong': -75.151,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Philadelphia',
#   'StateCode': 'PA',
#   'Latitude': 39.95,
#   'Longitude': -75.151,
#   'ParameterName': 'PM10',
#   'AQI': 22,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 8,
#   'csaFullName': 'Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area',
#   'csaPrimaryCity': 'Philadelphia',
#   'csaPrimaryCityState': 'PA',
#   'csaPopulation2018Estimate': 7204035,
#   'csaPopulation2010Census': 7067807,
#   'csaPrimaryCityLat': 39.9526,
#   'csaPrimaryCityLong': -75.1652,
#   'csaPrimaryCityZip': '19107',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 39.95,
#   'csaSearchLong': -75.151,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Houston-Galveston-Brazoria',
#   'StateCode': 'TX',
#   'Latitude': 29.751,
#   'Longitude': -95.351,
#   'ParameterName': 'OZONE',
#   'AQI': 29,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 9,
#   'csaFullName': 'Houston-The Woodlands, TX Combined Statistical Area',
#   'csaPrimaryCity': 'Houston',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 7197883,
#   'csaPopulation2010Census': 6114562,
#   'csaPrimaryCityLat': 29.7604,
#   'csaPrimaryCityLong': -95.3698,
#   'csaPrimaryCityZip': '77002',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.751,
#   'csaSearchLong': -95.351,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Houston-Galveston-Brazoria',
#   'StateCode': 'TX',
#   'Latitude': 29.751,
#   'Longitude': -95.351,
#   'ParameterName': 'PM2.5',
#   'AQI': 56,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 9,
#   'csaFullName': 'Houston-The Woodlands, TX Combined Statistical Area',
#   'csaPrimaryCity': 'Houston',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 7197883,
#   'csaPopulation2010Census': 6114562,
#   'csaPrimaryCityLat': 29.7604,
#   'csaPrimaryCityLong': -95.3698,
#   'csaPrimaryCityZip': '77002',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.751,
#   'csaSearchLong': -95.351,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Miami',
#   'StateCode': 'FL',
#   'Latitude': 25.776,
#   'Longitude': -80.211,
#   'ParameterName': 'OZONE',
#   'AQI': 36,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 10,
#   'csaFullName': 'Miami-Port St. Lucie-Fort Lauderdale, FL Combined Statistical Area',
#   'csaPrimaryCity': 'Miami',
#   'csaPrimaryCityState': 'FL',
#   'csaPopulation2018Estimate': 6913262,
#   'csaPopulation2010Census': 6199860,
#   'csaPrimaryCityLat': 25.7617,
#   'csaPrimaryCityLong': -80.1918,
#   'csaPrimaryCityZip': '33133',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 25.776,
#   'csaSearchLong': -80.211,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Miami',
#   'StateCode': 'FL',
#   'Latitude': 25.776,
#   'Longitude': -80.211,
#   'ParameterName': 'PM2.5',
#   'AQI': 31,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 10,
#   'csaFullName': 'Miami-Port St. Lucie-Fort Lauderdale, FL Combined Statistical Area',
#   'csaPrimaryCity': 'Miami',
#   'csaPrimaryCityState': 'FL',
#   'csaPopulation2018Estimate': 6913262,
#   'csaPopulation2010Census': 6199860,
#   'csaPrimaryCityLat': 25.7617,
#   'csaPrimaryCityLong': -80.1918,
#   'csaPrimaryCityZip': '33133',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 25.776,
#   'csaSearchLong': -80.211,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Atlanta',
#   'StateCode': 'GA',
#   'Latitude': 33.65,
#   'Longitude': -84.43,
#   'ParameterName': 'OZONE',
#   'AQI': 40,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 11,
#   'csaFullName': 'Atlanta–Athens-Clarke County–Sandy Springs, GA-AL Combined Statistical Area',
#   'csaPrimaryCity': 'Atlanta',
#   'csaPrimaryCityState': 'GA',
#   'csaPopulation2018Estimate': 6775511,
#   'csaPopulation2010Census': 6054858,
#   'csaPrimaryCityLat': 33.749,
#   'csaPrimaryCityLong': -84.388,
#   'csaPrimaryCityZip': '30334',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 33.65,
#   'csaSearchLong': -84.43,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Atlanta',
#   'StateCode': 'GA',
#   'Latitude': 33.65,
#   'Longitude': -84.43,
#   'ParameterName': 'PM2.5',
#   'AQI': 76,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 11,
#   'csaFullName': 'Atlanta–Athens-Clarke County–Sandy Springs, GA-AL Combined Statistical Area',
#   'csaPrimaryCity': 'Atlanta',
#   'csaPrimaryCityState': 'GA',
#   'csaPopulation2018Estimate': 6775511,
#   'csaPopulation2010Census': 6054858,
#   'csaPrimaryCityLat': 33.749,
#   'csaPrimaryCityLong': -84.388,
#   'csaPrimaryCityZip': '30334',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 33.65,
#   'csaSearchLong': -84.43,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Atlanta',
#   'StateCode': 'GA',
#   'Latitude': 33.65,
#   'Longitude': -84.43,
#   'ParameterName': 'PM10',
#   'AQI': 24,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 11,
#   'csaFullName': 'Atlanta–Athens-Clarke County–Sandy Springs, GA-AL Combined Statistical Area',
#   'csaPrimaryCity': 'Atlanta',
#   'csaPrimaryCityState': 'GA',
#   'csaPopulation2018Estimate': 6775511,
#   'csaPopulation2010Census': 6054858,
#   'csaPrimaryCityLat': 33.749,
#   'csaPrimaryCityLong': -84.388,
#   'csaPrimaryCityZip': '30334',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 33.65,
#   'csaSearchLong': -84.43,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Detroit',
#   'StateCode': 'MI',
#   'Latitude': 42.233,
#   'Longitude': -83.333,
#   'ParameterName': 'OZONE',
#   'AQI': 36,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 12,
#   'csaFullName': 'Detroit-Warren-Ann Arbor, MI Combined Statistical Area',
#   'csaPrimaryCity': 'Detroit',
#   'csaPrimaryCityState': 'MI',
#   'csaPopulation2018Estimate': 5353002,
#   'csaPopulation2010Census': 5318744,
#   'csaPrimaryCityLat': 42.3314,
#   'csaPrimaryCityLong': -83.0458,
#   'csaPrimaryCityZip': '48226',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 42.233,
#   'csaSearchLong': -83.333,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Detroit',
#   'StateCode': 'MI',
#   'Latitude': 42.233,
#   'Longitude': -83.333,
#   'ParameterName': 'PM2.5',
#   'AQI': 53,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 12,
#   'csaFullName': 'Detroit-Warren-Ann Arbor, MI Combined Statistical Area',
#   'csaPrimaryCity': 'Detroit',
#   'csaPrimaryCityState': 'MI',
#   'csaPopulation2018Estimate': 5353002,
#   'csaPopulation2010Census': 5318744,
#   'csaPrimaryCityLat': 42.3314,
#   'csaPrimaryCityLong': -83.0458,
#   'csaPrimaryCityZip': '48226',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 42.233,
#   'csaSearchLong': -83.333,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Detroit',
#   'StateCode': 'MI',
#   'Latitude': 42.233,
#   'Longitude': -83.333,
#   'ParameterName': 'PM10',
#   'AQI': 18,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 12,
#   'csaFullName': 'Detroit-Warren-Ann Arbor, MI Combined Statistical Area',
#   'csaPrimaryCity': 'Detroit',
#   'csaPrimaryCityState': 'MI',
#   'csaPopulation2018Estimate': 5353002,
#   'csaPopulation2010Census': 5318744,
#   'csaPrimaryCityLat': 42.3314,
#   'csaPrimaryCityLong': -83.0458,
#   'csaPrimaryCityZip': '48226',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 42.233,
#   'csaSearchLong': -83.333,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'MST',
#   'ReportingArea': 'Phoenix',
#   'StateCode': 'AZ',
#   'Latitude': 33.543,
#   'Longitude': -112.071,
#   'ParameterName': 'OZONE',
#   'AQI': 46,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 13,
#   'csaFullName': 'Phoenix-Mesa, AZ Combined Statistical Area',
#   'csaPrimaryCity': 'Phoenix',
#   'csaPrimaryCityState': 'AZ',
#   'csaPopulation2018Estimate': 4911851,
#   'csaPopulation2010Census': 4246484,
#   'csaPrimaryCityLat': 33.4484,
#   'csaPrimaryCityLong': -112.074,
#   'csaPrimaryCityZip': '85004',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.543,
#   'csaSearchLong': -112.071,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'MST',
#   'ReportingArea': 'Phoenix',
#   'StateCode': 'AZ',
#   'Latitude': 33.543,
#   'Longitude': -112.071,
#   'ParameterName': 'PM2.5',
#   'AQI': 21,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 13,
#   'csaFullName': 'Phoenix-Mesa, AZ Combined Statistical Area',
#   'csaPrimaryCity': 'Phoenix',
#   'csaPrimaryCityState': 'AZ',
#   'csaPopulation2018Estimate': 4911851,
#   'csaPopulation2010Census': 4246484,
#   'csaPrimaryCityLat': 33.4484,
#   'csaPrimaryCityLong': -112.074,
#   'csaPrimaryCityZip': '85004',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.543,
#   'csaSearchLong': -112.071,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'MST',
#   'ReportingArea': 'Phoenix',
#   'StateCode': 'AZ',
#   'Latitude': 33.543,
#   'Longitude': -112.071,
#   'ParameterName': 'PM10',
#   'AQI': 43,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 13,
#   'csaFullName': 'Phoenix-Mesa, AZ Combined Statistical Area',
#   'csaPrimaryCity': 'Phoenix',
#   'csaPrimaryCityState': 'AZ',
#   'csaPopulation2018Estimate': 4911851,
#   'csaPopulation2010Census': 4246484,
#   'csaPrimaryCityLat': 33.4484,
#   'csaPrimaryCityLong': -112.074,
#   'csaPrimaryCityZip': '85004',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 33.543,
#   'csaSearchLong': -112.071,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Seattle-Bellevue-Kent Valley',
#   'StateCode': 'WA',
#   'Latitude': 47.562,
#   'Longitude': -122.3405,
#   'ParameterName': 'OZONE',
#   'AQI': 31,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 14,
#   'csaFullName': 'Seattle-Tacoma, WA Combined Statistical Area',
#   'csaPrimaryCity': 'Seattle',
#   'csaPrimaryCityState': 'WA',
#   'csaPopulation2018Estimate': 4853364,
#   'csaPopulation2010Census': 4274767,
#   'csaPrimaryCityLat': 47.6062,
#   'csaPrimaryCityLong': -122.3321,
#   'csaPrimaryCityZip': '98164',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 47.562,
#   'csaSearchLong': -122.3405,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Seattle-Bellevue-Kent Valley',
#   'StateCode': 'WA',
#   'Latitude': 47.562,
#   'Longitude': -122.3405,
#   'ParameterName': 'PM2.5',
#   'AQI': 39,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 14,
#   'csaFullName': 'Seattle-Tacoma, WA Combined Statistical Area',
#   'csaPrimaryCity': 'Seattle',
#   'csaPrimaryCityState': 'WA',
#   'csaPopulation2018Estimate': 4853364,
#   'csaPopulation2010Census': 4274767,
#   'csaPrimaryCityLat': 47.6062,
#   'csaPrimaryCityLong': -122.3321,
#   'csaPrimaryCityZip': '98164',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 47.562,
#   'csaSearchLong': -122.3405,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Orlando',
#   'StateCode': 'FL',
#   'Latitude': 28.505,
#   'Longitude': -81.374,
#   'ParameterName': 'OZONE',
#   'AQI': 46,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 15,
#   'csaFullName': 'Orlando-Lakeland-Deltona, FL Combined Statistical Area',
#   'csaPrimaryCity': 'Orlando',
#   'csaPrimaryCityState': 'FL',
#   'csaPopulation2018Estimate': 4096575,
#   'csaPopulation2010Census': 3447946,
#   'csaPrimaryCityLat': 28.5383,
#   'csaPrimaryCityLong': -81.3792,
#   'csaPrimaryCityZip': '32801',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 28.505,
#   'csaSearchLong': -81.374,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Orlando',
#   'StateCode': 'FL',
#   'Latitude': 28.505,
#   'Longitude': -81.374,
#   'ParameterName': 'PM2.5',
#   'AQI': 13,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 15,
#   'csaFullName': 'Orlando-Lakeland-Deltona, FL Combined Statistical Area',
#   'csaPrimaryCity': 'Orlando',
#   'csaPrimaryCityState': 'FL',
#   'csaPopulation2018Estimate': 4096575,
#   'csaPopulation2010Census': 3447946,
#   'csaPrimaryCityLat': 28.5383,
#   'csaPrimaryCityLong': -81.3792,
#   'csaPrimaryCityZip': '32801',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 28.505,
#   'csaSearchLong': -81.374,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Minneapolis-St. Paul',
#   'StateCode': 'MN',
#   'Latitude': 44.955,
#   'Longitude': -93.185,
#   'ParameterName': 'OZONE',
#   'AQI': 15,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 16,
#   'csaFullName': 'Minneapolis-St. Paul, MN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Minneapolis',
#   'csaPrimaryCityState': 'MN',
#   'csaPopulation2018Estimate': 4014593,
#   'csaPopulation2010Census': 3721504,
#   'csaPrimaryCityLat': 44.9778,
#   'csaPrimaryCityLong': -93.265,
#   'csaPrimaryCityZip': '55415',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 44.955,
#   'csaSearchLong': -93.185,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Minneapolis-St. Paul',
#   'StateCode': 'MN',
#   'Latitude': 44.955,
#   'Longitude': -93.185,
#   'ParameterName': 'PM2.5',
#   'AQI': 60,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 16,
#   'csaFullName': 'Minneapolis-St. Paul, MN-WI Combined Statistical Area',
#   'csaPrimaryCity': 'Minneapolis',
#   'csaPrimaryCityState': 'MN',
#   'csaPopulation2018Estimate': 4014593,
#   'csaPopulation2010Census': 3721504,
#   'csaPrimaryCityLat': 44.9778,
#   'csaPrimaryCityLong': -93.265,
#   'csaPrimaryCityZip': '55415',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 44.955,
#   'csaSearchLong': -93.185,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Cleveland-Akron-Lorain',
#   'StateCode': 'OH',
#   'Latitude': 41.0814,
#   'Longitude': -81.519,
#   'ParameterName': 'OZONE',
#   'AQI': 43,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 17,
#   'csaFullName': 'Cleveland-Akron-Canton, OH Combined Statistical Area',
#   'csaPrimaryCity': 'Cleveland',
#   'csaPrimaryCityState': 'OH',
#   'csaPopulation2018Estimate': 3599264,
#   'csaPopulation2010Census': 3630166,
#   'csaPrimaryCityLat': 41.4993,
#   'csaPrimaryCityLong': -81.6944,
#   'csaPrimaryCityZip': '44113',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 41.0814,
#   'csaSearchLong': -81.519,
#   'csaSearchRadius': 50},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Cleveland-Akron-Lorain',
#   'StateCode': 'OH',
#   'Latitude': 41.0814,
#   'Longitude': -81.519,
#   'ParameterName': 'PM2.5',
#   'AQI': 55,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 17,
#   'csaFullName': 'Cleveland-Akron-Canton, OH Combined Statistical Area',
#   'csaPrimaryCity': 'Cleveland',
#   'csaPrimaryCityState': 'OH',
#   'csaPopulation2018Estimate': 3599264,
#   'csaPopulation2010Census': 3630166,
#   'csaPrimaryCityLat': 41.4993,
#   'csaPrimaryCityLong': -81.6944,
#   'csaPrimaryCityZip': '44113',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 41.0814,
#   'csaSearchLong': -81.519,
#   'csaSearchRadius': 50},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Cleveland-Akron-Lorain',
#   'StateCode': 'OH',
#   'Latitude': 41.0814,
#   'Longitude': -81.519,
#   'ParameterName': 'PM10',
#   'AQI': 31,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 17,
#   'csaFullName': 'Cleveland-Akron-Canton, OH Combined Statistical Area',
#   'csaPrimaryCity': 'Cleveland',
#   'csaPrimaryCityState': 'OH',
#   'csaPopulation2018Estimate': 3599264,
#   'csaPopulation2010Census': 3630166,
#   'csaPrimaryCityLat': 41.4993,
#   'csaPrimaryCityLong': -81.6944,
#   'csaPrimaryCityZip': '44113',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 41.0814,
#   'csaSearchLong': -81.519,
#   'csaSearchRadius': 50},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'MST',
#   'ReportingArea': 'Denver/Boulder',
#   'StateCode': 'CO',
#   'Latitude': 39.768,
#   'Longitude': -104.873,
#   'ParameterName': 'OZONE',
#   'AQI': 64,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 18,
#   'csaFullName': 'Denver-Aurora, CO Combined Statistical Area',
#   'csaPrimaryCity': 'Denver',
#   'csaPrimaryCityState': 'CO',
#   'csaPopulation2018Estimate': 3572798,
#   'csaPopulation2010Census': 3090874,
#   'csaPrimaryCityLat': 39.7392,
#   'csaPrimaryCityLong': -104.9903,
#   'csaPrimaryCityZip': '80202',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-06:00',
#   'csaSearchLat': 39.768,
#   'csaSearchLong': -104.873,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'MST',
#   'ReportingArea': 'Denver/Boulder',
#   'StateCode': 'CO',
#   'Latitude': 39.768,
#   'Longitude': -104.873,
#   'ParameterName': 'PM2.5',
#   'AQI': 26,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 18,
#   'csaFullName': 'Denver-Aurora, CO Combined Statistical Area',
#   'csaPrimaryCity': 'Denver',
#   'csaPrimaryCityState': 'CO',
#   'csaPopulation2018Estimate': 3572798,
#   'csaPopulation2010Census': 3090874,
#   'csaPrimaryCityLat': 39.7392,
#   'csaPrimaryCityLong': -104.9903,
#   'csaPrimaryCityZip': '80202',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-06:00',
#   'csaSearchLat': 39.768,
#   'csaSearchLong': -104.873,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'MST',
#   'ReportingArea': 'Denver/Boulder',
#   'StateCode': 'CO',
#   'Latitude': 39.768,
#   'Longitude': -104.873,
#   'ParameterName': 'PM10',
#   'AQI': 33,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 18,
#   'csaFullName': 'Denver-Aurora, CO Combined Statistical Area',
#   'csaPrimaryCity': 'Denver',
#   'csaPrimaryCityState': 'CO',
#   'csaPopulation2018Estimate': 3572798,
#   'csaPopulation2010Census': 3090874,
#   'csaPrimaryCityLat': 39.7392,
#   'csaPrimaryCityLong': -104.9903,
#   'csaPrimaryCityZip': '80202',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-06:00',
#   'csaSearchLat': 39.768,
#   'csaSearchLong': -104.873,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Portland',
#   'StateCode': 'OR',
#   'Latitude': 45.538,
#   'Longitude': -122.656,
#   'ParameterName': 'OZONE',
#   'AQI': 41,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 19,
#   'csaFullName': 'Portland-Vancouver-Salem, OR-WA Combined Statistical Area',
#   'csaPrimaryCity': 'Portland',
#   'csaPrimaryCityState': 'OR',
#   'csaPopulation2018Estimate': 3239335,
#   'csaPopulation2010Census': 2921408,
#   'csaPrimaryCityLat': 45.5051,
#   'csaPrimaryCityLong': -122.675,
#   'csaPrimaryCityZip': '97201',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 45.538,
#   'csaSearchLong': -122.656,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Portland',
#   'StateCode': 'OR',
#   'Latitude': 45.538,
#   'Longitude': -122.656,
#   'ParameterName': 'PM2.5',
#   'AQI': 20,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 19,
#   'csaFullName': 'Portland-Vancouver-Salem, OR-WA Combined Statistical Area',
#   'csaPrimaryCity': 'Portland',
#   'csaPrimaryCityState': 'OR',
#   'csaPopulation2018Estimate': 3239335,
#   'csaPopulation2010Census': 2921408,
#   'csaPrimaryCityLat': 45.5051,
#   'csaPrimaryCityLong': -122.675,
#   'csaPrimaryCityZip': '97201',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 45.538,
#   'csaSearchLong': -122.656,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Saint Louis',
#   'StateCode': 'MO',
#   'Latitude': 38.75,
#   'Longitude': -90.383,
#   'ParameterName': 'OZONE',
#   'AQI': 39,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 20,
#   'csaFullName': 'St. Louis-St. Charles-Farmington, MO-IL Combined Statistical Area',
#   'csaPrimaryCity': 'St. Louis',
#   'csaPrimaryCityState': 'MO',
#   'csaPopulation2018Estimate': 2909777,
#   'csaPopulation2010Census': 2892497,
#   'csaPrimaryCityLat': 38.627,
#   'csaPrimaryCityLong': -90.1994,
#   'csaPrimaryCityZip': '63103',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 38.75,
#   'csaSearchLong': -90.383,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Saint Louis',
#   'StateCode': 'MO',
#   'Latitude': 38.75,
#   'Longitude': -90.383,
#   'ParameterName': 'PM2.5',
#   'AQI': 40,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 20,
#   'csaFullName': 'St. Louis-St. Charles-Farmington, MO-IL Combined Statistical Area',
#   'csaPrimaryCity': 'St. Louis',
#   'csaPrimaryCityState': 'MO',
#   'csaPopulation2018Estimate': 2909777,
#   'csaPopulation2010Census': 2892497,
#   'csaPrimaryCityLat': 38.627,
#   'csaPrimaryCityLong': -90.1994,
#   'csaPrimaryCityZip': '63103',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 38.75,
#   'csaSearchLong': -90.383,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Saint Louis',
#   'StateCode': 'MO',
#   'Latitude': 38.75,
#   'Longitude': -90.383,
#   'ParameterName': 'PM10',
#   'AQI': 40,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 20,
#   'csaFullName': 'St. Louis-St. Charles-Farmington, MO-IL Combined Statistical Area',
#   'csaPrimaryCity': 'St. Louis',
#   'csaPrimaryCityState': 'MO',
#   'csaPopulation2018Estimate': 2909777,
#   'csaPopulation2010Census': 2892497,
#   'csaPrimaryCityLat': 38.627,
#   'csaPrimaryCityLong': -90.1994,
#   'csaPrimaryCityZip': '63103',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 38.75,
#   'csaSearchLong': -90.383,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Mecklenburg County',
#   'StateCode': 'NC',
#   'Latitude': 35.227,
#   'Longitude': -80.843,
#   'ParameterName': 'OZONE',
#   'AQI': 46,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 21,
#   'csaFullName': 'Charlotte-Concord, NC-SC Combined Statistical Area',
#   'csaPrimaryCity': 'Charlotte',
#   'csaPrimaryCityState': 'NC',
#   'csaPopulation2018Estimate': 2753810,
#   'csaPopulation2010Census': 2402623,
#   'csaPrimaryCityLat': 35.2271,
#   'csaPrimaryCityLong': -80.8431,
#   'csaPrimaryCityZip': '28202',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 35.227,
#   'csaSearchLong': -80.843,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Mecklenburg County',
#   'StateCode': 'NC',
#   'Latitude': 35.227,
#   'Longitude': -80.843,
#   'ParameterName': 'PM2.5',
#   'AQI': 48,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 21,
#   'csaFullName': 'Charlotte-Concord, NC-SC Combined Statistical Area',
#   'csaPrimaryCity': 'Charlotte',
#   'csaPrimaryCityState': 'NC',
#   'csaPopulation2018Estimate': 2753810,
#   'csaPopulation2010Census': 2402623,
#   'csaPrimaryCityLat': 35.2271,
#   'csaPrimaryCityLong': -80.8431,
#   'csaPrimaryCityZip': '28202',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 35.227,
#   'csaSearchLong': -80.843,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Sacramento',
#   'StateCode': 'CA',
#   'Latitude': 38.567,
#   'Longitude': -121.467,
#   'ParameterName': 'OZONE',
#   'AQI': 36,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 22,
#   'csaFullName': 'Sacramento-Roseville, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Sacramento',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 2619754,
#   'csaPopulation2010Census': 2414783,
#   'csaPrimaryCityLat': 38.5816,
#   'csaPrimaryCityLong': -121.4944,
#   'csaPrimaryCityZip': '95814',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 38.567,
#   'csaSearchLong': -121.467,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Sacramento',
#   'StateCode': 'CA',
#   'Latitude': 38.567,
#   'Longitude': -121.467,
#   'ParameterName': 'PM2.5',
#   'AQI': 14,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 22,
#   'csaFullName': 'Sacramento-Roseville, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Sacramento',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 2619754,
#   'csaPopulation2010Census': 2414783,
#   'csaPrimaryCityLat': 38.5816,
#   'csaPrimaryCityLong': -121.4944,
#   'csaPrimaryCityZip': '95814',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 38.567,
#   'csaSearchLong': -121.467,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Sacramento',
#   'StateCode': 'CA',
#   'Latitude': 38.567,
#   'Longitude': -121.467,
#   'ParameterName': 'PM10',
#   'AQI': 7,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 22,
#   'csaFullName': 'Sacramento-Roseville, CA Combined Statistical Area',
#   'csaPrimaryCity': 'Sacramento',
#   'csaPrimaryCityState': 'CA',
#   'csaPopulation2018Estimate': 2619754,
#   'csaPopulation2010Census': 2414783,
#   'csaPrimaryCityLat': 38.5816,
#   'csaPrimaryCityLong': -121.4944,
#   'csaPrimaryCityZip': '95814',
#   'csaTimeZone': 'Pacific',
#   'csaStandardTimeUtcOffset': '-08:00',
#   'csaDaylightSavingsTimeUtcOffset': '-07:00',
#   'csaSearchLat': 38.567,
#   'csaSearchLong': -121.467,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Pittsburgh',
#   'StateCode': 'PA',
#   'Latitude': 40.434,
#   'Longitude': -79.984,
#   'ParameterName': 'OZONE',
#   'AQI': 40,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 23,
#   'csaFullName': 'Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area',
#   'csaPrimaryCity': 'Pittsburgh',
#   'csaPrimaryCityState': 'PA',
#   'csaPopulation2018Estimate': 2612492,
#   'csaPopulation2010Census': 2660727,
#   'csaPrimaryCityLat': 40.4406,
#   'csaPrimaryCityLong': -79.9959,
#   'csaPrimaryCityZip': '15222',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.434,
#   'csaSearchLong': -79.984,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Pittsburgh',
#   'StateCode': 'PA',
#   'Latitude': 40.434,
#   'Longitude': -79.984,
#   'ParameterName': 'PM2.5',
#   'AQI': 46,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 23,
#   'csaFullName': 'Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area',
#   'csaPrimaryCity': 'Pittsburgh',
#   'csaPrimaryCityState': 'PA',
#   'csaPopulation2018Estimate': 2612492,
#   'csaPopulation2010Census': 2660727,
#   'csaPrimaryCityLat': 40.4406,
#   'csaPrimaryCityLong': -79.9959,
#   'csaPrimaryCityZip': '15222',
#   'csaTimeZone': 'Eastern',
#   'csaStandardTimeUtcOffset': '-05:00',
#   'csaDaylightSavingsTimeUtcOffset': '-04:00',
#   'csaSearchLat': 40.434,
#   'csaSearchLong': -79.984,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'MST',
#   'ReportingArea': 'Salt Lake City',
#   'StateCode': 'UT',
#   'Latitude': 40.777,
#   'Longitude': -111.93,
#   'ParameterName': 'OZONE',
#   'AQI': 43,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 24,
#   'csaFullName': 'Salt Lake City-Provo-Orem, UT Combined Statistical Area',
#   'csaPrimaryCity': 'Salt Lake City',
#   'csaPrimaryCityState': 'UT',
#   'csaPopulation2018Estimate': 2606548,
#   'csaPopulation2010Census': 2271696,
#   'csaPrimaryCityLat': 40.7608,
#   'csaPrimaryCityLong': -111.891,
#   'csaPrimaryCityZip': '84101',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-06:00',
#   'csaSearchLat': 40.777,
#   'csaSearchLong': -111.93,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'MST',
#   'ReportingArea': 'Salt Lake City',
#   'StateCode': 'UT',
#   'Latitude': 40.777,
#   'Longitude': -111.93,
#   'ParameterName': 'PM2.5',
#   'AQI': 25,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 24,
#   'csaFullName': 'Salt Lake City-Provo-Orem, UT Combined Statistical Area',
#   'csaPrimaryCity': 'Salt Lake City',
#   'csaPrimaryCityState': 'UT',
#   'csaPopulation2018Estimate': 2606548,
#   'csaPopulation2010Census': 2271696,
#   'csaPrimaryCityLat': 40.7608,
#   'csaPrimaryCityLong': -111.891,
#   'csaPrimaryCityZip': '84101',
#   'csaTimeZone': 'Mountain',
#   'csaStandardTimeUtcOffset': '-07:00',
#   'csaDaylightSavingsTimeUtcOffset': '-06:00',
#   'csaSearchLat': 40.777,
#   'csaSearchLong': -111.93,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'OZONE',
#   'AQI': 29,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25},
#  {'DateObserved': '2020-04-07 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'San Antonio',
#   'StateCode': 'TX',
#   'Latitude': 29.417,
#   'Longitude': -98.484,
#   'ParameterName': 'PM2.5',
#   'AQI': 58,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'csaRank': 25,
#   'csaFullName': 'San Antonio-New Braunfels-Pearsall, TX Combined Statistical Area',
#   'csaPrimaryCity': 'San Antonio',
#   'csaPrimaryCityState': 'TX',
#   'csaPopulation2018Estimate': 2555933,
#   'csaPopulation2010Census': 2175934,
#   'csaPrimaryCityLat': 29.4241,
#   'csaPrimaryCityLong': -98.4936,
#   'csaPrimaryCityZip': '78205',
#   'csaTimeZone': 'Central',
#   'csaStandardTimeUtcOffset': '-06:00',
#   'csaDaylightSavingsTimeUtcOffset': '-05:00',
#   'csaSearchLat': 29.417,
#   'csaSearchLong': -98.484,
#   'csaSearchRadius': 25}]
