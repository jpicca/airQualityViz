# %% [markdown]
# #### Import Dependencies & needed API Keys

# %%
import pandas as pd
import requests

# import os
# import sys
import datetime
# from datetime import datetime
# from os.path import expanduser

from config import airNowApiKeyShane, airNowApiKeyAudelia, airNowApiKeyCenez, airNowApiKeyJoseph, airNowApiKeyJoey
from largest_combined_statistical_areas import largest_combined_statistical_areas

# %%
# Get data for: first 7 days of each month; 5 years (2015 through 2019); top 10 cities;
# use counter to use different API keys (500 per hour)

# %% [markdown]
# #### Set output CSV data file filepath variable

# %%
output_data_filepath = "output_data/"

# %% [markdown]
# #### Setup counters and empty list and dict to hold data

# %%
# Setup Counters
attemptCounter = 1
recordSetCounter = 1
recordCounter= 1

# Setup empty 
dataList = []

# %% [markdown]
# #### Create a list of dates to iterate through (first 7 days of each month, 2015 to 2019)

# %%
# Set Date Range to use for API
# startDate = '2015-01-01'
startDate = '2020-01-01'
# endDate = '2019-12-31'
endDate = '2020-01-31'

# Create a list of dates (from Start to End)
dateList = pd.date_range(startDate, endDate).strftime("%Y-%m-%d").tolist()
# print(dateList)

# Create empty list to append dates within a given range to in for loop
datesToUseList = []

# Loop through dateList and append only dates that are within the range of days (of month) to the datesToUseList
for date in dateList:
    day = (datetime.datetime.strptime(date, "%Y-%m-%d")).day
#     if day in range(1,8):
    if day in range(1,2):
        datesToUseList.append(date)
#         print(f"KEEP: {date} is in range")
    else:
#         print(f"REMOVE: {date} is OUT OF RANGE")
        pass

# print(datesToUseList)
len(datesToUseList)
# Out:
# 1

# %% [markdown]
# #### Set API URL and API key variables to pass through in the API request

# %% [markdown]
# #### Setup API Call Function and Parameters

# %%
# # def apiCallLatLongHistorical(lat, long, obsDate, obsTime, apiKey):

# response = []

# # API Parameters
# # lat = lat
# # long = long
# # obsDate = obsDate
# # obsTime = obsTime
# # apiKey = apiKey

# params = {}
# params["baseURL"] = "http://www.airnowapi.org/aq/observation/latLong/historical/?format=application/json"
# # params["lat"] = ""
# # params["lat"] = lat
# params["lat"] = "32.7767"
# # params["long"] = ""
# # params["long"] = long
# params["long"] = "-96.7970"
# # params["obsDate"] = ""
# # params["obsDate"] = obsDate
# params["obsDate"] = "2020-04-06"
# # params["obsTime"] = ""
# # params["obsTime"] = obsTime
# params["obsTime"] = "00-0000"
# params["searchDistance"] = "25"
# # params["apiKey"] = ""
# # params["apiKey"] = apiKey
# params["apiKey"] = airNowApiKeyShane

# # Build API Request URL, passing through parameters
# # requestURL = f'{params["baseURL"]}&latitude={params["lat"]}&longitude={params["long"]}&date={params["obsDate"]}T{params["obsTime"]}&distance={params["searchDistance"]}&API_KEY={params["apiKey"]}'

# requestURL = params["baseURL"] \
#             + "&latitude=" + params["lat"] \
#             + "&longitude=" + params["long"] \
#             + "&date=" + params["obsDate"] \
#             + "T" + params["obsTime"] \
#             + "&distance=" + params["searchDistance"] \
#             + "&API_KEY=" + params["apiKey"]

# # try:
#     # Execute requests.get, passing through required API parameters
# response = requests.get(requestURL).json()
# responseCode = requests.get(requestURL)

# # Loop through response, appending each element (dictionary) as a new item in the dataList list
# for i in range(len(response)):
#     dataList.append(response[i])
        
# #     # Logger: Print status message
# #     print("--------------------------------------------------")
# #     print(f"Requesting AirNow API Data for LAT: {params['lat']}, LONG: {params['long']}, DATE: {params['obsDate']} & TIME: {params['obsTime']}...")
# #     print(requestURL)
# #     print("--------------------------------------------------")


# # except Exception as e:
# #     print("--------------------------------------------------")
# #     print("ERROR: Unable to perform AirNow API request for LAT: {params['lat']}, LONG: {params['long']}, DATE: {params['obsDate']} & TIME: {params['obsTime']}.")
# #     print("%s" % e)
# #     print("--------------------------------------------------")

# %%
print(requestURL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-389651ef35a5> in <module>
# ----> 1 print(requestURL)
#
# NameError: name 'requestURL' is not defined

# %%
responseCode

# %%
dataList

# %%
response

# %%
len(response)

# %%
# def apiCallLatLongHistorical(lat, long, obsDate, obsTime, apiKey):
def apiCallLatLongHistorical(cityRank, cityName, cityCSA, cityState, cityPopulation2018Estimate, cityPopulation2010Census, cityLat, cityLong, cityZip, obsDate, obsTime, apiKey):
    response = []

    # API Parameters
#     lat = lat
#     long = long
#     obsDate = obsDate
#     obsTime = obsTime
#     apiKey = apiKey

    params = {}
    params["baseURL"] = "http://www.airnowapi.org/aq/observation/latLong/historical/?format=application/json"
    params["lat"] = f"{cityLat}"
    params["long"] = f"{cityLong}"
    params["obsDate"] = f"{obsDate}"
#     params["obsTime"] = f"{obsTime}"
    params["obsTime"] = "00-0000"
    params["searchDistance"] = "25"
    params["apiKey"] = apiKey

    # Build API Request URL, passing through parameters
    requestURL = params["baseURL"] \
                + "&latitude=" + params["lat"] \
                + "&longitude=" + params["long"] \
                + "&date=" + params["obsDate"] \
                + "T" + params["obsTime"] \
                + "&distance=" + params["searchDistance"] \
                + "&API_KEY=" + params["apiKey"]

    try:
        # Logger: Print status message
        print("--------------------------------------------------")
#           print(f"Requesting AirNow API Data for LAT: {params['lat']}, LONG: {params['long']}, DATE: {params['obsDate']} & TIME: {params['obsTime']}...")
        print(f"Requesting AirNow API Data for CITY: {cityName}, {cityState}, LAT: {params['lat']}, LONG: {params['long']}, DATE: {params['obsDate']} & TIME: {params['obsTime']}...")
#         print(requestURL)
        
        # Execute requests.get, passing through built requestURL
        response = requests.get(requestURL).json()
        responseCode = requests.get(requestURL)
        print(f"Number of results found: {len(response)}")
        print("--------------------------------------------------")

        # Loop through response, appending each element (dictionary) as a new item in the dataList list
        for i in range(len(response)):
            
            response[i]["AQICategoryNumber"] = response[i]["Category"]["Number"]
            response[i]["AQICategory"] = response[i]["Category"]["Name"]
            del response[i]["Category"]
            
            response[i]["cityRank"] = cityRank
            response[i]["cityName"] = cityName
            response[i]["cityCSA"] = cityCSA
            response[i]["cityState"] = cityState
            response[i]["cityPopulation2018Estimate"] = cityPopulation2018Estimate
            response[i]["cityPopulation2010Census"] = cityPopulation2010Census
            response[i]["cityLat"] = cityLat
            response[i]["cityLong"] = cityLong
            response[i]["cityZip"] = cityZip
            
            dataList.append(response[i])

    except Exception as e:
        print("--------------------------------------------------")
        print(f"ERROR: Unable to perform AirNow API request for LAT: {params['lat']}, LONG: {params['long']}, DATE: {params['obsDate']} & TIME: {params['obsTime']}.")
        print("%s" % e)
        print("--------------------------------------------------")
        pass
    
# if __name__ == "__apiCallLatLongHistorical__":
#     apiCallLatLongHistorical()

# %%
# for date in datesToUseList:
# #     apiCallLatLongHistorical(lat, long, obsDate, obsTime, apiKey)
#     apiCallLatLongHistorical("32.7767", "-96.7970", date, "00-0000", airNowApiKeyShane)

# %%
# dataList
len(dataList)
# Out:
# 23

# %%
# for i in dataList:
#     print(i)
#     print(i["Category"])
#     del i["Category"]
#     print(i)

# %%
dataList
# Out:
# [{'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'OZONE',
#   'AQI': 25,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 1,
#   'cityName': 'New York City',
#   'cityCSA': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'cityState': 'NY',
#   'cityPopulation2018Estimate': 22679948,
#   'cityPopulation2010Census': 22255491,
#   'cityLat': 40.7128,
#   'cityLong': -74.006,
#   'cityZip': 10001},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Newark',
#   'StateCode': 'NJ',
#   'Latitude': 40.7267,
#   'Longitude': -74.1442,
#   'ParameterName': 'PM2.5',
#   'AQI': 19,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 1,
#   'cityName': 'New York City',
#   'cityCSA': 'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#   'cityState': 'NY',
#   'cityPopulation2018Estimate': 22679948,
#   'cityPopulation2010Census': 22255491,
#   'cityLat': 40.7128,
#   'cityLong': -74.006,
#   'cityZip': 10001},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'OZONE',
#   'AQI': 38,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 2,
#   'cityName': 'Los Angeles',
#   'cityCSA': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'cityState': 'CA',
#   'cityPopulation2018Estimate': 18764814,
#   'cityPopulation2010Census': 17877006,
#   'cityLat': 34.0522,
#   'cityLong': -118.2437,
#   'cityZip': 90001},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'PM2.5',
#   'AQI': 88,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'cityRank': 2,
#   'cityName': 'Los Angeles',
#   'cityCSA': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'cityState': 'CA',
#   'cityPopulation2018Estimate': 18764814,
#   'cityPopulation2010Census': 17877006,
#   'cityLat': 34.0522,
#   'cityLong': -118.2437,
#   'cityZip': 90001},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'Central LA CO',
#   'StateCode': 'CA',
#   'Latitude': 34.0663,
#   'Longitude': -118.2266,
#   'ParameterName': 'PM10',
#   'AQI': 30,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 2,
#   'cityName': 'Los Angeles',
#   'cityCSA': 'Los Angeles-Long Beach, CA Combined Statistical Area',
#   'cityState': 'CA',
#   'cityPopulation2018Estimate': 18764814,
#   'cityPopulation2010Census': 17877006,
#   'cityLat': 34.0522,
#   'cityLong': -118.2437,
#   'cityZip': 90001},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'OZONE',
#   'AQI': 28,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 3,
#   'cityName': 'Chicago',
#   'cityCSA': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'cityState': 'IL',
#   'cityPopulation2018Estimate': 9866910,
#   'cityPopulation2010Census': 9840929,
#   'cityLat': 41.8781,
#   'cityLong': -87.6298,
#   'cityZip': 60601},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Chicago',
#   'StateCode': 'IL',
#   'Latitude': 41.964,
#   'Longitude': -87.659,
#   'ParameterName': 'PM2.5',
#   'AQI': 32,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 3,
#   'cityName': 'Chicago',
#   'cityCSA': 'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#   'cityState': 'IL',
#   'cityPopulation2018Estimate': 9866910,
#   'cityPopulation2010Census': 9840929,
#   'cityLat': 41.8781,
#   'cityLong': -87.6298,
#   'cityZip': 60601},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'OZONE',
#   'AQI': 34,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 4,
#   'cityName': 'Washington',
#   'cityCSA': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'cityState': 'DC',
#   'cityPopulation2018Estimate': 9778360,
#   'cityPopulation2010Census': 9032651,
#   'cityLat': 38.9072,
#   'cityLong': -77.0369,
#   'cityZip': 20001},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM2.5',
#   'AQI': 22,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 4,
#   'cityName': 'Washington',
#   'cityCSA': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'cityState': 'DC',
#   'cityPopulation2018Estimate': 9778360,
#   'cityPopulation2010Census': 9032651,
#   'cityLat': 38.9072,
#   'cityLong': -77.0369,
#   'cityZip': 20001},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Metropolitan Washington',
#   'StateCode': 'DC',
#   'Latitude': 38.919,
#   'Longitude': -77.013,
#   'ParameterName': 'PM10',
#   'AQI': 9,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 4,
#   'cityName': 'Washington',
#   'cityCSA': 'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#   'cityState': 'DC',
#   'cityPopulation2018Estimate': 9778360,
#   'cityPopulation2010Census': 9032651,
#   'cityLat': 38.9072,
#   'cityLong': -77.0369,
#   'cityZip': 20001},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'San Francisco',
#   'StateCode': 'CA',
#   'Latitude': 37.75,
#   'Longitude': -122.43,
#   'ParameterName': 'OZONE',
#   'AQI': 27,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 5,
#   'cityName': 'San Francisco',
#   'cityCSA': 'San Jose-San Francisco-Oakland, CA Combined Statistical Area',
#   'cityState': 'CA',
#   'cityPopulation2018Estimate': 9666055,
#   'cityPopulation2010Census': 8923942,
#   'cityLat': 37.7749,
#   'cityLong': -122.4194,
#   'cityZip': 94102},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'PST',
#   'ReportingArea': 'San Francisco',
#   'StateCode': 'CA',
#   'Latitude': 37.75,
#   'Longitude': -122.43,
#   'ParameterName': 'PM2.5',
#   'AQI': 37,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 5,
#   'cityName': 'San Francisco',
#   'cityCSA': 'San Jose-San Francisco-Oakland, CA Combined Statistical Area',
#   'cityState': 'CA',
#   'cityPopulation2018Estimate': 9666055,
#   'cityPopulation2010Census': 8923942,
#   'cityLat': 37.7749,
#   'cityLong': -122.4194,
#   'cityZip': 94102},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Boston',
#   'StateCode': 'MA',
#   'Latitude': 42.351,
#   'Longitude': -71.051,
#   'ParameterName': 'OZONE',
#   'AQI': 24,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 6,
#   'cityName': 'Boston',
#   'cityCSA': 'Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area',
#   'cityState': 'MA',
#   'cityPopulation2018Estimate': 8285407,
#   'cityPopulation2010Census': 7893376,
#   'cityLat': 42.3601,
#   'cityLong': -71.0589,
#   'cityZip': 2108},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Boston',
#   'StateCode': 'MA',
#   'Latitude': 42.351,
#   'Longitude': -71.051,
#   'ParameterName': 'PM2.5',
#   'AQI': 7,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 6,
#   'cityName': 'Boston',
#   'cityCSA': 'Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area',
#   'cityState': 'MA',
#   'cityPopulation2018Estimate': 8285407,
#   'cityPopulation2010Census': 7893376,
#   'cityLat': 42.3601,
#   'cityLong': -71.0589,
#   'cityZip': 2108},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Dallas-Fort Worth',
#   'StateCode': 'TX',
#   'Latitude': 32.767,
#   'Longitude': -96.783,
#   'ParameterName': 'OZONE',
#   'AQI': 35,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 7,
#   'cityName': 'Dallas',
#   'cityCSA': 'Dallas-Fort Worth, TX-OK Combined Statistical Area',
#   'cityState': 'TX',
#   'cityPopulation2018Estimate': 7957493,
#   'cityPopulation2010Census': 6816237,
#   'cityLat': 32.7767,
#   'cityLong': -96.797,
#   'cityZip': 75201},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Dallas-Fort Worth',
#   'StateCode': 'TX',
#   'Latitude': 32.767,
#   'Longitude': -96.783,
#   'ParameterName': 'PM2.5',
#   'AQI': 58,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'cityRank': 7,
#   'cityName': 'Dallas',
#   'cityCSA': 'Dallas-Fort Worth, TX-OK Combined Statistical Area',
#   'cityState': 'TX',
#   'cityPopulation2018Estimate': 7957493,
#   'cityPopulation2010Census': 6816237,
#   'cityLat': 32.7767,
#   'cityLong': -96.797,
#   'cityZip': 75201},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Philadelphia',
#   'StateCode': 'PA',
#   'Latitude': 39.95,
#   'Longitude': -75.151,
#   'ParameterName': 'OZONE',
#   'AQI': 30,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 8,
#   'cityName': 'Philadelphia',
#   'cityCSA': 'Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area',
#   'cityState': 'PA',
#   'cityPopulation2018Estimate': 7204035,
#   'cityPopulation2010Census': 7067807,
#   'cityLat': 39.9526,
#   'cityLong': -75.1652,
#   'cityZip': 19019},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Philadelphia',
#   'StateCode': 'PA',
#   'Latitude': 39.95,
#   'Longitude': -75.151,
#   'ParameterName': 'PM2.5',
#   'AQI': 51,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'cityRank': 8,
#   'cityName': 'Philadelphia',
#   'cityCSA': 'Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area',
#   'cityState': 'PA',
#   'cityPopulation2018Estimate': 7204035,
#   'cityPopulation2010Census': 7067807,
#   'cityLat': 39.9526,
#   'cityLong': -75.1652,
#   'cityZip': 19019},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Philadelphia',
#   'StateCode': 'PA',
#   'Latitude': 39.95,
#   'Longitude': -75.151,
#   'ParameterName': 'PM10',
#   'AQI': 10,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 8,
#   'cityName': 'Philadelphia',
#   'cityCSA': 'Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area',
#   'cityState': 'PA',
#   'cityPopulation2018Estimate': 7204035,
#   'cityPopulation2010Census': 7067807,
#   'cityLat': 39.9526,
#   'cityLong': -75.1652,
#   'cityZip': 19019},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Houston-Galveston-Brazoria',
#   'StateCode': 'TX',
#   'Latitude': 29.751,
#   'Longitude': -95.351,
#   'ParameterName': 'OZONE',
#   'AQI': 37,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 9,
#   'cityName': 'Houston-The Woodlands, TX Combined Statistical Area',
#   'cityCSA': 'Houston',
#   'cityState': 'TX',
#   'cityPopulation2018Estimate': 7197883,
#   'cityPopulation2010Census': 6114562,
#   'cityLat': 29.7604,
#   'cityLong': -95.3698,
#   'cityZip': 77001},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'CST',
#   'ReportingArea': 'Houston-Galveston-Brazoria',
#   'StateCode': 'TX',
#   'Latitude': 29.751,
#   'Longitude': -95.351,
#   'ParameterName': 'PM2.5',
#   'AQI': 152,
#   'AQICategoryNumber': 4,
#   'AQICategory': 'Unhealthy',
#   'cityRank': 9,
#   'cityName': 'Houston-The Woodlands, TX Combined Statistical Area',
#   'cityCSA': 'Houston',
#   'cityState': 'TX',
#   'cityPopulation2018Estimate': 7197883,
#   'cityPopulation2010Census': 6114562,
#   'cityLat': 29.7604,
#   'cityLong': -95.3698,
#   'cityZip': 77001},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Miami',
#   'StateCode': 'FL',
#   'Latitude': 25.776,
#   'Longitude': -80.211,
#   'ParameterName': 'OZONE',
#   'AQI': 49,
#   'AQICategoryNumber': 1,
#   'AQICategory': 'Good',
#   'cityRank': 10,
#   'cityName': 'Miami',
#   'cityCSA': 'Miami-Port St. Lucie-Fort Lauderdale, FL Combined Statistical Area',
#   'cityState': 'FL',
#   'cityPopulation2018Estimate': 6913262,
#   'cityPopulation2010Census': 6199860,
#   'cityLat': 25.7617,
#   'cityLong': -80.1918,
#   'cityZip': 33101},
#  {'DateObserved': '2020-01-01 ',
#   'HourObserved': 0,
#   'LocalTimeZone': 'EST',
#   'ReportingArea': 'Miami',
#   'StateCode': 'FL',
#   'Latitude': 25.776,
#   'Longitude': -80.211,
#   'ParameterName': 'PM2.5',
#   'AQI': 73,
#   'AQICategoryNumber': 2,
#   'AQICategory': 'Moderate',
#   'cityRank': 10,
#   'cityName': 'Miami',
#   'cityCSA': 'Miami-Port St. Lucie-Fort Lauderdale, FL Combined Statistical Area',
#   'cityState': 'FL',
#   'cityPopulation2018Estimate': 6913262,
#   'cityPopulation2010Census': 6199860,
#   'cityLat': 25.7617,
#   'cityLong': -80.1918,
#   'cityZip': 33101}]

# %%
largest_combined_statistical_areas

# %%
datesToUseList

# %%
responseData

# %%
for city in largest_combined_statistical_areas:
    cityRank = city["rank"]
    cityName = city["name"]
    cityCSA = city["csa_name"]
    cityState = city["state"]
    cityPopulation2018Estimate = city["population"]["2018_estimate"]
    cityPopulation2010Census = city["population"]["2010_census"]
    cityLat = city["location"]["lat"]
    cityLong = city["location"]["long"]
    cityZip = city["location"]["zip_code"]
    
    for date in datesToUseList:
#         apiCallLatLongHistorical(lat, long, obsDate, obsTime, apiKey)
#         apiCallLatLongHistorical("32.7767", "-96.7970", date, "00-0000", airNowApiKeyShane)
#         apiCallLatLongHistorical(f"{cityLat}", f"{cityLong}", date, "00-0000", airNowApiKeyShane)
#         apiCallLatLongHistorical(cityRank, cityName, cityCSA, cityState, cityPopulation2018Estimate, cityPopulation2010Census, f"{cityLat}", f"{cityLong}", cityZip, f"{date}", "00-0000", airNowApiKeyShane)
        apiCallLatLongHistorical(cityRank, cityName, cityCSA, cityState, cityPopulation2018Estimate, cityPopulation2010Census, cityLat, cityLong, cityZip, date, "00-0000", airNowApiKeyShane)
# Out:
# --------------------------------------------------
# Requesting AirNow API Data for CITY: New York City, NY, LAT: 40.7128, LONG: -74.006, DATE: 2020-01-01 & TIME: 00-0000...
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for CITY: Los Angeles, CA, LAT: 34.0522, LONG: -118.2437, DATE: 2020-01-01 & TIME: 00-0000...
# Number of results found: 3
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for CITY: Chicago, IL, LAT: 41.8781, LONG: -87.6298, DATE: 2020-01-01 & TIME: 00-0000...
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for CITY: Washington, DC, LAT: 38.9072, LONG: -77.0369, DATE: 2020-01-01 & TIME: 00-0000...
# Number of results found: 3
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for CITY: San Francisco, CA, LAT: 37.7749, LONG: -122.4194, DATE: 2020-01-01 & TIME: 00-0000...
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2020-01-01 & TIME: 00-0000...
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for CITY: Dallas, TX, LAT: 32.7767, LONG: -96.797, DATE: 2020-01-01 & TIME: 00-0000...
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for CITY: Philadelphia, PA, LAT: 39.9526, LONG: -75.1652, DATE: 2020-01-01 & TIME: 00-0000...
# Number of results found: 3
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for CITY: Houston-The Woodlands, TX Combined Statistical Area, TX, LAT: 29.7604, LONG: -95.3698, DATE: 2020-01-01 & TIME: 00-0000...
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for CITY: Miami, FL, LAT: 25.7617, LONG: -80.1918, DATE: 2020-01-01 & TIME: 00-0000...
# Number of results found: 2
# --------------------------------------------------

# %%
# for city in largest_combined_statistical_areas:
# #     print(city)
#     print(city["rank"])
#     print(city["name"])
#     print(city["csa_name"])
#     print(city["state"])
#     print(city["capital"])
#     print(city["capital_of"])
#     print(city["population"]["2018_estimate"])
#     print(city["population"]["2010_census"])
#     print(city["location"]["lat"])
#     print(city["location"]["long"])
#     print(city["location"]["zip_code"])

# %%
# for city in largest_combined_statistical_areas:
# for date in datesToUseList:
# #     apiCallLatLongHistorical(lat, long, obsDate, obsTime, apiKey)
#     apiCallLatLongHistorical("32.7767", "-96.7970", date, "00-0000", airNowApiKeyShane)
#     for
