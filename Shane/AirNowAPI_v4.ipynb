# %% [markdown]
# #### Import Dependencies & needed API Keys

# %%
import pandas as pd
import requests
import datetime
from datetime import datetime as dt
from time import sleep

from config import airNowApiKeyShane, airNowApiKeyAudelia, airNowApiKeyCenez, airNowApiKeyJoseph, airNowApiKeyJoey
from largest_combined_statistical_areas import largest_combined_statistical_areas

# %% [markdown]
# #### Setup counters, empty list to hold data amd API Key Variables to be used

# %%
# Setup Counters
counterAttempts = 0
counterAttemptsPerAPI = 0
counterAPI = 1

# Setup empty list
apiData = []

# Setup API Key Variables
airNowApiKey1 = airNowApiKeyShane
airNowApiKey2 = airNowApiKeyAudelia
airNowApiKey3 = airNowApiKeyCenez
airNowApiKey4 = airNowApiKeyJoseph
airNowApiKey5 = airNowApiKeyJoey

# %% [markdown]
# #### Create a list of dates to iterate through (first 7 days of each month, 2015 to 2019)

# %%
# Set Date Range to use for API
startDate = '2015-01-01'
# startDate = '2020-01-01'
endDate = '2019-12-31'
# endDate = '2020-01-31'

# Create a list of dates (from Start to End)
dateList = pd.date_range(startDate, endDate).strftime("%Y-%m-%d").tolist()
# print(dateList)

# Create empty list to append dates within a given range to in for loop
datesToUseList = []

# Loop through dateList and append only dates that are within the range of days (of month) to the datesToUseList
for date in dateList:
    day = (datetime.datetime.strptime(date, "%Y-%m-%d")).day
    if day in range(1,8):
        datesToUseList.append(date)
#         print(f"KEEP: {date} is in range")
    else:
#         print(f"REMOVE: {date} is OUT OF RANGE")
        pass

# print(datesToUseList)
len(datesToUseList)
# Out:
# 420

# %% [markdown]
# #### Setup API Call Function and with URL, API Key, and variables to pass through in the requests.get() API call

# %%
def apiCallLatLongHistorical(cityRank, cityName, cityCSA, cityState, cityPopulation2018Estimate, cityPopulation2010Census, cityLat, cityLong, cityZip, obsDate, obsTime, apiKey, apiKeyUsed, counterAttempts, counterAttemptsPerAPI, counterAPI):
    
    # Empty response list variable every time function is called
    response = []
    
    # Set API Parameters to be passed through to API requests.get
    params = {}
    params["baseURL"] = "http://www.airnowapi.org/aq/observation/latLong/historical/?format=application/json"
    params["lat"] = f"{cityLat}"
    params["long"] = f"{cityLong}"
    params["obsDate"] = f"{obsDate}"
    params["obsTime"] = "00-0000" # f"{obsTime}"
    params["searchDistance"] = "25"
    params["apiKey"] = apiKey

    # Build API Request URL, passing through parameters
    requestURL = params["baseURL"] \
                + "&latitude=" + params["lat"] \
                + "&longitude=" + params["long"] \
                + "&date=" + params["obsDate"] \
                + "T" + params["obsTime"] \
                + "&distance=" + params["searchDistance"] \
                + "&API_KEY=" + params["apiKey"]

    
    # Logger: Print status message
    print("--------------------------------------------------")
    print("Requesting AirNow API Data for...")
    print("     **************************************************")
    print(f"CITY: {cityName}, {cityState} | LAT: {params['lat']} | LONG: {params['long']} | DATE: {params['obsDate']} | TIME: {params['obsTime']}")
    print(f"ATTEMPT:{counterAttempts} | BATCH/API: {counterAPI} | ATTEMPT PER BATCH/API: {counterAttemptsPerAPI} | API Key Used: {apiKeyUsed}")
    print("     **************************************************")
#     print(requestURL)
    
    # Set up error handling in the even there is an error in the API requests.get()
    try:
        
        # Execute requests.get, passing through built requestURL
        response = requests.get(requestURL).json()
        responseCode = requests.get(requestURL)
        
        print(f"Number of results found: {len(response)}")
        print("--------------------------------------------------")

        # Loop through response, appending each element (dictionary) as a new item in the apiData list
        for i in range(len(response)):
            
            # Break out the response "Category" Key value (another dictionary) into two separate values (to easily convert later to a csv, if needed)
            response[i]["AQICategoryNumber"] = response[i]["Category"]["Number"]
            response[i]["AQICategory"] = response[i]["Category"]["Name"]
            
            # Delete the "Category" Key value (another dictionary) from response since separate key: values were created and this is no longer needed
            del response[i]["Category"]
            
            # Add values brought in from the largest_combined_statistical_areas dictionary / json object to the response
            response[i]["cityRank"] = cityRank
            response[i]["cityName"] = cityName
            response[i]["cityCSA"] = cityCSA
            response[i]["cityState"] = cityState
            response[i]["cityPopulation2018Estimate"] = cityPopulation2018Estimate
            response[i]["cityPopulation2010Census"] = cityPopulation2010Census
            response[i]["cityLat"] = cityLat
            response[i]["cityLong"] = cityLong
            response[i]["cityZip"] = cityZip
            
            # Append the response to the apiData list
            apiData.append(response[i])

    except Exception as e:
        print(f"ERROR: Unable to perform AirNow API request for CITY: {cityName}, {cityState}, LAT: {params['lat']}, LONG: {params['long']}, DATE: {params['obsDate']} & TIME: {params['obsTime']}.")
        print("%s" % e)
        print("--------------------------------------------------")
        pass
    
# if __name__ == "__apiCallLatLongHistorical__":
#     apiCallLatLongHistorical()

# %% [markdown]
# #### Loop through cities and dates, while updating variables and passing them through to the apiCallLatLongHistorical Function

# %%
# Loop through cities in the largest_combined_statistical_areas dictionary / json object
for city in largest_combined_statistical_areas:
    
    # Loop through datesToUseList, calling the apiCallLatLongHistorical function, passing through variables    
    for date in datesToUseList:
    
        # Set varaiable values to pass into the apiCallLatLongHistorical function
        cityRank = city["rank"]
        cityName = city["name"]
        cityCSA = city["csa_name"]
        cityState = city["state"]
        cityPopulation2018Estimate = city["population"]["2018_estimate"]
        cityPopulation2010Census = city["population"]["2010_census"]
        cityLat = city["location"]["lat"]
        cityLong = city["location"]["long"]
        cityZip = city["location"]["zip_code"]
        
        # Update overall attempt counter
        counterAttempts += 1
        
        # Once 250 attempts have been made for all five API Keys, reset counterAttemptsPerAPI, counterAPI and apiKey then sleep for one hour (3600 seconds)
        if counterAttemptsPerAPI >= 250 and counterAPI >= 5:
            counterAttemptsPerAPI = 1
            counterAPI = 1
            apiKey = airNowApiKey1
            sleep(3600)
#             sleep(3)
            print("*****  250 per API for all APIs avialable reached | RESET counterAttemptsPerAPI, counterAPI, apiKey & SLEEP  *****")

        # Once 250 attempts have been made for the currently used API Key, update counterAPI so a new apiKey is used next time through, reset counterAttemptsPerAPI
        elif counterAttemptsPerAPI >= 250:
            counterAPI += 1
            counterAttemptsPerAPI = 1
            print("*****  250 per current API reached | RESET counterAttemptsPerAPI; UPDATE counterAPI & apiKey  *****")
            
        else:
            counterAttemptsPerAPI += 1

        # Set apiKey variable based on the counterAPI variable
        if counterAPI == 1:
            apiKey = airNowApiKey1
            apiKeyUsed = "airNowApiKey1"
        elif counterAPI == 2:
            apiKey = airNowApiKey2
            apiKeyUsed = "airNowApiKey2"
        elif counterAPI == 3:
            apiKey = airNowApiKey3
            apiKeyUsed = "airNowApiKey3"
        elif counterAPI == 4:
            apiKey = airNowApiKey4
            apiKeyUsed = "airNowApiKey4"
        elif counterAPI == 5:
            apiKey = airNowApiKey5
            apiKeyUsed = "airNowApiKey5"
        
        # Call the apiCallLatLongHistorical function, passing through updated variables as parameters
        apiCallLatLongHistorical(cityRank, cityName, cityCSA, cityState, cityPopulation2018Estimate, cityPopulation2010Census, cityLat, cityLong, cityZip, date, "00-0000", apiKey, apiKeyUsed, counterAttempts, counterAttemptsPerAPI, counterAPI)
# Out:
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-01-01 | TIME: 00-0000
# ATTEMPT:1 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 1 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-01-02 | TIME: 00-0000
# ATTEMPT:2 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 2 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-01-03 | TIME: 00-0000
# ATTEMPT:3 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 3 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-01-04 | TIME: 00-0000
# ATTEMPT:4 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 4 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-01-05 | TIME: 00-0000
# ATTEMPT:5 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 5 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-01-06 | TIME: 00-0000
# ATTEMPT:6 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 6 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-01-07 | TIME: 00-0000
# ATTEMPT:7 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 7 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-02-01 | TIME: 00-0000
# ATTEMPT:8 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 8 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-02-02 | TIME: 00-0000
# ATTEMPT:9 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 9 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-02-03 | TIME: 00-0000
# ATTEMPT:10 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 10 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-02-04 | TIME: 00-0000
# ATTEMPT:11 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 11 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-02-05 | TIME: 00-0000
# ATTEMPT:12 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 12 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-02-06 | TIME: 00-0000
# ATTEMPT:13 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 13 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-02-07 | TIME: 00-0000
# ATTEMPT:14 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 14 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-03-01 | TIME: 00-0000
# ATTEMPT:15 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 15 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-03-02 | TIME: 00-0000
# ATTEMPT:16 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 16 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-03-03 | TIME: 00-0000
# ATTEMPT:17 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 17 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-03-04 | TIME: 00-0000
# ATTEMPT:18 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 18 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-03-05 | TIME: 00-0000
# ATTEMPT:19 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 19 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-03-06 | TIME: 00-0000
# ATTEMPT:20 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 20 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-03-07 | TIME: 00-0000
# ATTEMPT:21 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 21 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-04-01 | TIME: 00-0000
# ATTEMPT:22 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 22 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-04-02 | TIME: 00-0000
# ATTEMPT:23 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 23 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-04-03 | TIME: 00-0000
# ATTEMPT:24 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 24 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-04-04 | TIME: 00-0000
# ATTEMPT:25 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 25 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-04-05 | TIME: 00-0000
# ATTEMPT:26 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 26 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-04-06 | TIME: 00-0000
# ATTEMPT:27 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 27 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-04-07 | TIME: 00-0000
# ATTEMPT:28 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 28 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-05-01 | TIME: 00-0000
# ATTEMPT:29 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 29 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-05-02 | TIME: 00-0000
# ATTEMPT:30 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 30 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-05-03 | TIME: 00-0000
# ATTEMPT:31 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 31 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-05-04 | TIME: 00-0000
# ATTEMPT:32 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 32 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-05-05 | TIME: 00-0000
# ATTEMPT:33 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 33 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-05-06 | TIME: 00-0000
# ATTEMPT:34 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 34 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-05-07 | TIME: 00-0000
# ATTEMPT:35 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 35 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-06-01 | TIME: 00-0000
# ATTEMPT:36 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 36 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-06-02 | TIME: 00-0000
# ATTEMPT:37 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 37 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-06-03 | TIME: 00-0000
# ATTEMPT:38 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 38 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-06-04 | TIME: 00-0000
# ATTEMPT:39 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 39 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-06-05 | TIME: 00-0000
# ATTEMPT:40 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 40 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-06-06 | TIME: 00-0000
# ATTEMPT:41 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 41 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-06-07 | TIME: 00-0000
# ATTEMPT:42 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 42 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-07-01 | TIME: 00-0000
# ATTEMPT:43 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 43 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-07-02 | TIME: 00-0000
# ATTEMPT:44 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 44 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-07-03 | TIME: 00-0000
# ATTEMPT:45 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 45 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-07-04 | TIME: 00-0000
# ATTEMPT:46 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 46 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-07-05 | TIME: 00-0000
# ATTEMPT:47 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 47 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-07-06 | TIME: 00-0000
# ATTEMPT:48 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 48 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-07-07 | TIME: 00-0000
# ATTEMPT:49 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 49 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-08-01 | TIME: 00-0000
# ATTEMPT:50 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 50 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-08-02 | TIME: 00-0000
# ATTEMPT:51 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 51 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-08-03 | TIME: 00-0000
# ATTEMPT:52 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 52 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-08-04 | TIME: 00-0000
# ATTEMPT:53 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 53 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-08-05 | TIME: 00-0000
# ATTEMPT:54 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 54 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-08-06 | TIME: 00-0000
# ATTEMPT:55 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 55 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-08-07 | TIME: 00-0000
# ATTEMPT:56 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 56 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-09-01 | TIME: 00-0000
# ATTEMPT:57 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 57 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-09-02 | TIME: 00-0000
# ATTEMPT:58 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 58 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-09-03 | TIME: 00-0000
# ATTEMPT:59 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 59 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-09-04 | TIME: 00-0000
# ATTEMPT:60 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 60 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-09-05 | TIME: 00-0000
# ATTEMPT:61 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 61 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-09-06 | TIME: 00-0000
# ATTEMPT:62 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 62 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-09-07 | TIME: 00-0000
# ATTEMPT:63 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 63 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-10-01 | TIME: 00-0000
# ATTEMPT:64 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 64 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-10-02 | TIME: 00-0000
# ATTEMPT:65 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 65 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-10-03 | TIME: 00-0000
# ATTEMPT:66 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 66 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-10-04 | TIME: 00-0000
# ATTEMPT:67 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 67 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-10-05 | TIME: 00-0000
# ATTEMPT:68 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 68 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-10-06 | TIME: 00-0000
# ATTEMPT:69 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 69 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-10-07 | TIME: 00-0000
# ATTEMPT:70 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 70 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-11-01 | TIME: 00-0000
# ATTEMPT:71 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 71 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-11-02 | TIME: 00-0000
# ATTEMPT:72 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 72 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-11-03 | TIME: 00-0000
# ATTEMPT:73 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 73 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-11-04 | TIME: 00-0000
# ATTEMPT:74 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 74 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-11-05 | TIME: 00-0000
# ATTEMPT:75 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 75 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-11-06 | TIME: 00-0000
# ATTEMPT:76 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 76 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-11-07 | TIME: 00-0000
# ATTEMPT:77 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 77 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-12-01 | TIME: 00-0000
# ATTEMPT:78 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 78 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-12-02 | TIME: 00-0000
# ATTEMPT:79 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 79 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-12-03 | TIME: 00-0000
# ATTEMPT:80 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 80 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-12-04 | TIME: 00-0000
# ATTEMPT:81 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 81 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-12-05 | TIME: 00-0000
# ATTEMPT:82 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 82 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-12-06 | TIME: 00-0000
# ATTEMPT:83 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 83 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2015-12-07 | TIME: 00-0000
# ATTEMPT:84 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 84 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-01-01 | TIME: 00-0000
# ATTEMPT:85 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 85 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-01-02 | TIME: 00-0000
# ATTEMPT:86 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 86 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-01-03 | TIME: 00-0000
# ATTEMPT:87 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 87 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-01-04 | TIME: 00-0000
# ATTEMPT:88 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 88 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-01-05 | TIME: 00-0000
# ATTEMPT:89 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 89 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-01-06 | TIME: 00-0000
# ATTEMPT:90 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 90 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-01-07 | TIME: 00-0000
# ATTEMPT:91 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 91 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-02-01 | TIME: 00-0000
# ATTEMPT:92 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 92 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-02-02 | TIME: 00-0000
# ATTEMPT:93 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 93 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-02-03 | TIME: 00-0000
# ATTEMPT:94 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 94 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-02-04 | TIME: 00-0000
# ATTEMPT:95 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 95 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-02-05 | TIME: 00-0000
# ATTEMPT:96 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 96 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-02-06 | TIME: 00-0000
# ATTEMPT:97 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 97 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-02-07 | TIME: 00-0000
# ATTEMPT:98 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 98 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-03-01 | TIME: 00-0000
# ATTEMPT:99 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 99 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-03-02 | TIME: 00-0000
# ATTEMPT:100 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 100 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-03-03 | TIME: 00-0000
# ATTEMPT:101 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 101 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-03-04 | TIME: 00-0000
# ATTEMPT:102 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 102 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-03-05 | TIME: 00-0000
# ATTEMPT:103 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 103 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-03-06 | TIME: 00-0000
# ATTEMPT:104 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 104 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-03-07 | TIME: 00-0000
# ATTEMPT:105 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 105 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-04-01 | TIME: 00-0000
# ATTEMPT:106 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 106 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: New York City, NY | LAT: 40.7128 | LONG: -74.006 | DATE: 2016-04-02 | TIME: 00-0000
# ATTEMPT:107 | BATCH/API: 1 | ATTEMPT PER BATCH/API: 107 | API Key Used: airNowApiKey1
#      **************************************************
# Number of results found: 2
# ...
# ATTEMPT:2481 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 477 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-07-03 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-07-04 | TIME: 00-0000
# ATTEMPT:2482 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 478 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-07-04 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-07-05 | TIME: 00-0000
# ATTEMPT:2483 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 479 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-07-05 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-07-06 | TIME: 00-0000
# ATTEMPT:2484 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 480 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-07-06 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-07-07 | TIME: 00-0000
# ATTEMPT:2485 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 481 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-07-07 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-08-01 | TIME: 00-0000
# ATTEMPT:2486 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 482 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-08-01 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-08-02 | TIME: 00-0000
# ATTEMPT:2487 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 483 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-08-02 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-08-03 | TIME: 00-0000
# ATTEMPT:2488 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 484 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-08-03 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-08-04 | TIME: 00-0000
# ATTEMPT:2489 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 485 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-08-04 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-08-05 | TIME: 00-0000
# ATTEMPT:2490 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 486 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-08-05 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-08-06 | TIME: 00-0000
# ATTEMPT:2491 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 487 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-08-06 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-08-07 | TIME: 00-0000
# ATTEMPT:2492 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 488 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-08-07 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-09-01 | TIME: 00-0000
# ATTEMPT:2493 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 489 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-09-01 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-09-02 | TIME: 00-0000
# ATTEMPT:2494 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 490 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-09-02 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-09-03 | TIME: 00-0000
# ATTEMPT:2495 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 491 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-09-03 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-09-04 | TIME: 00-0000
# ATTEMPT:2496 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 492 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-09-04 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-09-05 | TIME: 00-0000
# ATTEMPT:2497 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 493 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-09-05 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-09-06 | TIME: 00-0000
# ATTEMPT:2498 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 494 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-09-06 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-09-07 | TIME: 00-0000
# ATTEMPT:2499 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 495 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-09-07 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-10-01 | TIME: 00-0000
# ATTEMPT:2500 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 496 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-10-01 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-10-02 | TIME: 00-0000
# ATTEMPT:2501 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 497 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-10-02 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-10-03 | TIME: 00-0000
# ATTEMPT:2502 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 498 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-10-03 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-10-04 | TIME: 00-0000
# ATTEMPT:2503 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 499 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-10-04 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-10-05 | TIME: 00-0000
# ATTEMPT:2504 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 500 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-10-05 & TIME: 00-0000.
# 0
# --------------------------------------------------
# --------------------------------------------------
# Requesting AirNow API Data for...
#      **************************************************
# CITY: Boston, MA | LAT: 42.3601 | LONG: -71.0589 | DATE: 2019-10-06 | TIME: 00-0000
# ATTEMPT:2505 | BATCH/API: 5 | ATTEMPT PER BATCH/API: 501 | API Key Used: airNowApiKey5
#      **************************************************
# Number of results found: 1
# --------------------------------------------------
# ERROR: Unable to perform AirNow API request for CITY: Boston, MA, LAT: 42.3601, LONG: -71.0589, DATE: 2019-10-06 & TIME: 00-0000.
# 0
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-00fbc877ffa1> in <module>
#      25             counterAPI = 1
#      26             apiKey = airNowApiKey1
# ---> 27             sleep(3600)
#      28 #             sleep(3)
#      29             print("*****  500 per API for all APIs avialable reached | RESET counterAttemptsPerAPI, counterAPI, apiKey & SLEEP  *****")
#
# KeyboardInterrupt:

# %% [markdown]
# #### Check the number of records in the apiData list

# %%
# apiData
len(apiData)
# Out:
# 2730

# %% [markdown]
# #### Create DataFrame holding the values from teh apiData list

# %%
df = pd.DataFrame(apiData)

# Visualize the DataFrame
df
# Out:
#      DateObserved  HourObserved LocalTimeZone ReportingArea StateCode  \
# 0     2015-01-01              0           EST        Newark        NJ
# 1     2015-01-01              0           EST        Newark        NJ
# 2     2015-01-02              0           EST        Newark        NJ
# 3     2015-01-02              0           EST        Newark        NJ
# 4     2015-01-03              0           EST        Newark        NJ
# ...           ...           ...           ...           ...       ...
# 2725  2016-10-05              0           EST        Boston        MA
# 2726  2016-10-06              0           EST        Boston        MA
# 2727  2016-10-06              0           EST        Boston        MA
# 2728  2016-10-07              0           EST        Boston        MA
# 2729  2016-10-07              0           EST        Boston        MA
#
#       Latitude  Longitude ParameterName  AQI  AQICategoryNumber AQICategory  \
# 0      40.7267   -74.1442         OZONE   30                  1        Good
# 1      40.7267   -74.1442         PM2.5   65                  2    Moderate
# 2      40.7267   -74.1442         OZONE   24                  1        Good
# 3      40.7267   -74.1442         PM2.5   56                  2    Moderate
# 4      40.7267   -74.1442         OZONE    8                  1        Good
# ...        ...        ...           ...  ...                ...         ...
# 2725   42.3510   -71.0510         PM2.5   27                  1        Good
# 2726   42.3510   -71.0510         OZONE   20                  1        Good
# 2727   42.3510   -71.0510         PM2.5   44                  1        Good
# 2728   42.3510   -71.0510         OZONE   29                  1        Good
# 2729   42.3510   -71.0510         PM2.5   41                  1        Good
#
#       cityRank       cityName  \
# 0            1  New York City
# 1            1  New York City
# 2            1  New York City
# 3            1  New York City
# 4            1  New York City
# ...        ...            ...
# 2725         6         Boston
# 2726         6         Boston
# 2727         6         Boston
# 2728         6         Boston
# 2729         6         Boston
#
#                                                 cityCSA cityState  \
# 0     New York-Newark, NY-NJ-CT-PA Combined Statisti...        NY
# 1     New York-Newark, NY-NJ-CT-PA Combined Statisti...        NY
# 2     New York-Newark, NY-NJ-CT-PA Combined Statisti...        NY
# 3     New York-Newark, NY-NJ-CT-PA Combined Statisti...        NY
# 4     New York-Newark, NY-NJ-CT-PA Combined Statisti...        NY
# ...                                                 ...       ...
# 2725  Boston-Worcester-Providence, MA-RI-NH-CT Combi...        MA
# 2726  Boston-Worcester-Providence, MA-RI-NH-CT Combi...        MA
# 2727  Boston-Worcester-Providence, MA-RI-NH-CT Combi...        MA
# 2728  Boston-Worcester-Providence, MA-RI-NH-CT Combi...        MA
# 2729  Boston-Worcester-Providence, MA-RI-NH-CT Combi...        MA
#
#       cityPopulation2018Estimate  cityPopulation2010Census  cityLat  cityLong  \
# 0                       22679948                  22255491  40.7128  -74.0060
# 1                       22679948                  22255491  40.7128  -74.0060
# 2                       22679948                  22255491  40.7128  -74.0060
# 3                       22679948                  22255491  40.7128  -74.0060
# 4                       22679948                  22255491  40.7128  -74.0060
# ...                          ...                       ...      ...       ...
# 2725                     8285407                   7893376  42.3601  -71.0589
# 2726                     8285407                   7893376  42.3601  -71.0589
# 2727                     8285407                   7893376  42.3601  -71.0589
# 2728                     8285407                   7893376  42.3601  -71.0589
# 2729                     8285407                   7893376  42.3601  -71.0589
#
#       cityZip
# 0       10001
# 1       10001
# 2       10001
# 3       10001
# 4       10001
# ...       ...
# 2725     2108
# 2726     2108
# 2727     2108
# 2728     2108
# 2729     2108
#
# [2730 rows x 20 columns]

# %% [markdown]
# #### Set output data file filepath variable

# %%
output_data_filepath = "output_data/"

# %% [markdown]
# #### Create variables to create the CSV file name

# %%
timestamp = dt.now().strftime("%Y%m%d_%H%M%S")
output_file_name = f"AirNowAPI_{timestamp}"
# print(output_file_name)

# %% [markdown]
# #### Convert & export DataFrame to CSV and JSON files

# %%
df.to_csv(f"{output_data_filepath}{output_file_name}.csv", encoding="utf-8", index= False)

# %%
# df.to_json(f"{output_data_filepath}{output_file_name}.json")
